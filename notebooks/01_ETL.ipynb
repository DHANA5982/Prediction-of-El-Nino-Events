# %%
import os
import requests
from datetime import datetime, timedelta
import xarray as xr
import numpy as np
import pandas as pd

# %%
# === Ensure download directory exists ===
os.makedirs(download_dir, exist_ok=True)

# === Helper function to download a single file ==
def download_nc_file(date):
    filename = f"oisst-avhrr-v02r01.{date.strftime('%Y%m%d')}.nc"
    file_url = f"{base_url}/{date.year}{date.month:02d}/{filename}"
    local_path = os.path.join(download_dir, filename)

    if os.path.exists(local_path):
        print(f"Already downloaded: {filename}")
        return local_path

    print(f"Downloading: {file_url}")
    response = requests.get(file_url)
    if response.status_code == 200:
        with open(local_path, 'wb') as f:
            f.write(response.content)
        return local_path
    else:
        print(f"Failed to download {filename} (status {response.status_code})")
        return None

# %%
# === Helper function to extract Niño 3.4 SST from a file ===
def extract_nino34_sst(filepath):
    try:
        ds = xr.open_dataset(filepath)

        # Convert lon to 0–360 if needed
        if ds.lon.max() <= 180:
            ds = ds.assign_coords(lon=((ds.lon + 360) % 360))

        # Define Niño 3.4 box (5N–5S, 170W–120W => lat -5 to 5, lon 190 to 240)
        region = ds.sel(lat=slice(-5, 5), lon=slice(190, 240))
        sst = region['sst'].where(region['sst'] > -100)  # Mask land

        weights = np.cos(np.deg2rad(sst.lat))
        weighted_sst = sst.weighted(weights)

        sst_mean = weighted_sst.mean(dim=['lat', 'lon']).values.item()
        date = ds['time'].values.item()

        return {'date': pd.to_datetime(date), 'sst': round(sst_mean, 2)}
    except Exception as e:
        print(f"Error processing {filepath}: {e}")
        return None

# %%
# === USER SETTINGS ===
start_date = datetime(1981, 9, 1)
end_date = datetime(1997, 12, 31)
download_dir = "D:/GitHub/Prediction of El-Nino Events/data/raw/oisst_data"
base_url = "https://www.ncei.noaa.gov/data/sea-surface-temperature-optimum-interpolation/v2.1/access/avhrr"

# %%
# === Main Loop ===
current = start_date
records = []

while current <= end_date:
    file_path = download_nc_file(current)
    if file_path:
        result = extract_nino34_sst(file_path)
        if result:
            records.append(result)
    current += timedelta(days=1)

# === Save results to CSV by year ===
if records:
    df = pd.DataFrame(records)
    df.sort_values('date', inplace=True)
    
    # Group by year and save separate files
    df['year'] = pd.to_datetime(df['date']).dt.year
    
    for year in df['year'].unique():
        year_data = df[df['year'] == year].drop('year', axis=1)
        year_csv = f"D:/GitHub/Prediction of El-Nino Events/data/raw/csv/nino34_sst_{year}.csv"
        year_data.to_csv(year_csv, index=False)
        print(f"✅ Saved {year}: {len(year_data)} records to {year_csv}")
    
    print(f"\n📊 Total records processed: {len(df)}")
    print(f"📅 Years covered: {df['year'].min()} to {df['year'].max()}")
else:
    print("No data extracted.")
# Out:
# Already downloaded: oisst-avhrr-v02r01.19810901.nc
# Already downloaded: oisst-avhrr-v02r01.19810902.nc
# Already downloaded: oisst-avhrr-v02r01.19810903.nc
# Already downloaded: oisst-avhrr-v02r01.19810904.nc
# Already downloaded: oisst-avhrr-v02r01.19810905.nc
# Already downloaded: oisst-avhrr-v02r01.19810906.nc
# Already downloaded: oisst-avhrr-v02r01.19810907.nc
# Already downloaded: oisst-avhrr-v02r01.19810908.nc
# Already downloaded: oisst-avhrr-v02r01.19810909.nc
# Already downloaded: oisst-avhrr-v02r01.19810910.nc
# Already downloaded: oisst-avhrr-v02r01.19810906.nc
# Already downloaded: oisst-avhrr-v02r01.19810907.nc
# Already downloaded: oisst-avhrr-v02r01.19810908.nc
# Already downloaded: oisst-avhrr-v02r01.19810909.nc
# Already downloaded: oisst-avhrr-v02r01.19810910.nc
# Already downloaded: oisst-avhrr-v02r01.19810911.nc
# Already downloaded: oisst-avhrr-v02r01.19810912.nc
# Already downloaded: oisst-avhrr-v02r01.19810913.nc
# Already downloaded: oisst-avhrr-v02r01.19810914.nc
# Already downloaded: oisst-avhrr-v02r01.19810915.nc
# Already downloaded: oisst-avhrr-v02r01.19810911.nc
# Already downloaded: oisst-avhrr-v02r01.19810912.nc
# Already downloaded: oisst-avhrr-v02r01.19810913.nc
# Already downloaded: oisst-avhrr-v02r01.19810914.nc
# Already downloaded: oisst-avhrr-v02r01.19810915.nc
# Already downloaded: oisst-avhrr-v02r01.19810916.nc
# Already downloaded: oisst-avhrr-v02r01.19810917.nc
# Already downloaded: oisst-avhrr-v02r01.19810918.nc
# Already downloaded: oisst-avhrr-v02r01.19810919.nc
# Already downloaded: oisst-avhrr-v02r01.19810920.nc
# Already downloaded: oisst-avhrr-v02r01.19810916.nc
# Already downloaded: oisst-avhrr-v02r01.19810917.nc
# Already downloaded: oisst-avhrr-v02r01.19810918.nc
# Already downloaded: oisst-avhrr-v02r01.19810919.nc
# Already downloaded: oisst-avhrr-v02r01.19810920.nc
# Already downloaded: oisst-avhrr-v02r01.19810921.nc
# Already downloaded: oisst-avhrr-v02r01.19810922.nc
# Already downloaded: oisst-avhrr-v02r01.19810923.nc
# Already downloaded: oisst-avhrr-v02r01.19810921.nc
# Already downloaded: oisst-avhrr-v02r01.19810922.nc
# Already downloaded: oisst-avhrr-v02r01.19810923.nc
# Already downloaded: oisst-avhrr-v02r01.19810924.nc
# Already downloaded: oisst-avhrr-v02r01.19810925.nc
# Already downloaded: oisst-avhrr-v02r01.19810926.nc
# Already downloaded: oisst-avhrr-v02r01.19810927.nc
# Already downloaded: oisst-avhrr-v02r01.19810928.nc
# Already downloaded: oisst-avhrr-v02r01.19810929.nc
# Already downloaded: oisst-avhrr-v02r01.19810924.nc
# Already downloaded: oisst-avhrr-v02r01.19810925.nc
# Already downloaded: oisst-avhrr-v02r01.19810926.nc
# Already downloaded: oisst-avhrr-v02r01.19810927.nc
# Already downloaded: oisst-avhrr-v02r01.19810928.nc
# Already downloaded: oisst-avhrr-v02r01.19810929.nc
# Already downloaded: oisst-avhrr-v02r01.19810930.nc
# Already downloaded: oisst-avhrr-v02r01.19811001.nc
# Already downloaded: oisst-avhrr-v02r01.19811002.nc
# Already downloaded: oisst-avhrr-v02r01.19811003.nc
# Already downloaded: oisst-avhrr-v02r01.19811004.nc
# Already downloaded: oisst-avhrr-v02r01.19810930.nc
# Already downloaded: oisst-avhrr-v02r01.19811001.nc
# Already downloaded: oisst-avhrr-v02r01.19811002.nc
# Already downloaded: oisst-avhrr-v02r01.19811003.nc
# Already downloaded: oisst-avhrr-v02r01.19811004.nc
# Already downloaded: oisst-avhrr-v02r01.19811005.nc
# Already downloaded: oisst-avhrr-v02r01.19811006.nc
# Already downloaded: oisst-avhrr-v02r01.19811007.nc
# Already downloaded: oisst-avhrr-v02r01.19811008.nc
# Already downloaded: oisst-avhrr-v02r01.19811009.nc
# Already downloaded: oisst-avhrr-v02r01.19811010.nc
# Already downloaded: oisst-avhrr-v02r01.19811005.nc
# Already downloaded: oisst-avhrr-v02r01.19811006.nc
# Already downloaded: oisst-avhrr-v02r01.19811007.nc
# Already downloaded: oisst-avhrr-v02r01.19811008.nc
# Already downloaded: oisst-avhrr-v02r01.19811009.nc
# Already downloaded: oisst-avhrr-v02r01.19811010.nc
# Already downloaded: oisst-avhrr-v02r01.19811011.nc
# Already downloaded: oisst-avhrr-v02r01.19811012.nc
# Already downloaded: oisst-avhrr-v02r01.19811013.nc
# Already downloaded: oisst-avhrr-v02r01.19811014.nc
# Already downloaded: oisst-avhrr-v02r01.19811015.nc
# Already downloaded: oisst-avhrr-v02r01.19811011.nc
# Already downloaded: oisst-avhrr-v02r01.19811012.nc
# Already downloaded: oisst-avhrr-v02r01.19811013.nc
# Already downloaded: oisst-avhrr-v02r01.19811014.nc
# Already downloaded: oisst-avhrr-v02r01.19811015.nc
# Already downloaded: oisst-avhrr-v02r01.19811016.nc
# Already downloaded: oisst-avhrr-v02r01.19811017.nc
# Already downloaded: oisst-avhrr-v02r01.19811018.nc
# Already downloaded: oisst-avhrr-v02r01.19811019.nc
# Already downloaded: oisst-avhrr-v02r01.19811020.nc
# Already downloaded: oisst-avhrr-v02r01.19811016.nc
# Already downloaded: oisst-avhrr-v02r01.19811017.nc
# Already downloaded: oisst-avhrr-v02r01.19811018.nc
# Already downloaded: oisst-avhrr-v02r01.19811019.nc
# Already downloaded: oisst-avhrr-v02r01.19811020.nc
# Already downloaded: oisst-avhrr-v02r01.19811021.nc
# Already downloaded: oisst-avhrr-v02r01.19811022.nc
# Already downloaded: oisst-avhrr-v02r01.19811023.nc
# Already downloaded: oisst-avhrr-v02r01.19811024.nc
# Already downloaded: oisst-avhrr-v02r01.19811025.nc
# Already downloaded: oisst-avhrr-v02r01.19811021.nc
# Already downloaded: oisst-avhrr-v02r01.19811022.nc
# Already downloaded: oisst-avhrr-v02r01.19811023.nc
# Already downloaded: oisst-avhrr-v02r01.19811024.nc
# Already downloaded: oisst-avhrr-v02r01.19811025.nc
# Already downloaded: oisst-avhrr-v02r01.19811026.nc
# Already downloaded: oisst-avhrr-v02r01.19811027.nc
# Already downloaded: oisst-avhrr-v02r01.19811028.nc
# Already downloaded: oisst-avhrr-v02r01.19811029.nc
# Already downloaded: oisst-avhrr-v02r01.19811030.nc
# Already downloaded: oisst-avhrr-v02r01.19811031.nc
# Already downloaded: oisst-avhrr-v02r01.19811026.nc
# Already downloaded: oisst-avhrr-v02r01.19811027.nc
# Already downloaded: oisst-avhrr-v02r01.19811028.nc
# Already downloaded: oisst-avhrr-v02r01.19811029.nc
# Already downloaded: oisst-avhrr-v02r01.19811030.nc
# Already downloaded: oisst-avhrr-v02r01.19811031.nc
# Already downloaded: oisst-avhrr-v02r01.19811101.nc
# Already downloaded: oisst-avhrr-v02r01.19811102.nc
# Already downloaded: oisst-avhrr-v02r01.19811103.nc
# Already downloaded: oisst-avhrr-v02r01.19811104.nc
# Already downloaded: oisst-avhrr-v02r01.19811105.nc
# Already downloaded: oisst-avhrr-v02r01.19811101.nc
# Already downloaded: oisst-avhrr-v02r01.19811102.nc
# Already downloaded: oisst-avhrr-v02r01.19811103.nc
# Already downloaded: oisst-avhrr-v02r01.19811104.nc
# Already downloaded: oisst-avhrr-v02r01.19811105.nc
# Already downloaded: oisst-avhrr-v02r01.19811106.nc
# Already downloaded: oisst-avhrr-v02r01.19811107.nc
# Already downloaded: oisst-avhrr-v02r01.19811108.nc
# Already downloaded: oisst-avhrr-v02r01.19811109.nc
# Already downloaded: oisst-avhrr-v02r01.19811110.nc
# Already downloaded: oisst-avhrr-v02r01.19811106.nc
# Already downloaded: oisst-avhrr-v02r01.19811107.nc
# Already downloaded: oisst-avhrr-v02r01.19811108.nc
# Already downloaded: oisst-avhrr-v02r01.19811109.nc
# Already downloaded: oisst-avhrr-v02r01.19811110.nc
# Already downloaded: oisst-avhrr-v02r01.19811111.nc
# Already downloaded: oisst-avhrr-v02r01.19811112.nc
# Already downloaded: oisst-avhrr-v02r01.19811113.nc
# Already downloaded: oisst-avhrr-v02r01.19811114.nc
# Already downloaded: oisst-avhrr-v02r01.19811115.nc
# Already downloaded: oisst-avhrr-v02r01.19811111.nc
# Already downloaded: oisst-avhrr-v02r01.19811112.nc
# Already downloaded: oisst-avhrr-v02r01.19811113.nc
# Already downloaded: oisst-avhrr-v02r01.19811114.nc
# Already downloaded: oisst-avhrr-v02r01.19811115.nc
# Already downloaded: oisst-avhrr-v02r01.19811116.nc
# Already downloaded: oisst-avhrr-v02r01.19811117.nc
# Already downloaded: oisst-avhrr-v02r01.19811118.nc
# Already downloaded: oisst-avhrr-v02r01.19811119.nc
# Already downloaded: oisst-avhrr-v02r01.19811120.nc
# Already downloaded: oisst-avhrr-v02r01.19811121.nc
# Already downloaded: oisst-avhrr-v02r01.19811116.nc
# Already downloaded: oisst-avhrr-v02r01.19811117.nc
# Already downloaded: oisst-avhrr-v02r01.19811118.nc
# Already downloaded: oisst-avhrr-v02r01.19811119.nc
# Already downloaded: oisst-avhrr-v02r01.19811120.nc
# Already downloaded: oisst-avhrr-v02r01.19811121.nc
# Already downloaded: oisst-avhrr-v02r01.19811122.nc
# Already downloaded: oisst-avhrr-v02r01.19811123.nc
# Already downloaded: oisst-avhrr-v02r01.19811124.nc
# Already downloaded: oisst-avhrr-v02r01.19811125.nc
# Already downloaded: oisst-avhrr-v02r01.19811126.nc
# Already downloaded: oisst-avhrr-v02r01.19811127.nc
# Already downloaded: oisst-avhrr-v02r01.19811122.nc
# Already downloaded: oisst-avhrr-v02r01.19811123.nc
# Already downloaded: oisst-avhrr-v02r01.19811124.nc
# Already downloaded: oisst-avhrr-v02r01.19811125.nc
# Already downloaded: oisst-avhrr-v02r01.19811126.nc
# Already downloaded: oisst-avhrr-v02r01.19811127.nc
# Already downloaded: oisst-avhrr-v02r01.19811128.nc
# Already downloaded: oisst-avhrr-v02r01.19811129.nc
# Already downloaded: oisst-avhrr-v02r01.19811130.nc
# Already downloaded: oisst-avhrr-v02r01.19811201.nc
# Already downloaded: oisst-avhrr-v02r01.19811202.nc
# Already downloaded: oisst-avhrr-v02r01.19811128.nc
# Already downloaded: oisst-avhrr-v02r01.19811129.nc
# Already downloaded: oisst-avhrr-v02r01.19811130.nc
# Already downloaded: oisst-avhrr-v02r01.19811201.nc
# Already downloaded: oisst-avhrr-v02r01.19811202.nc
# Already downloaded: oisst-avhrr-v02r01.19811203.nc
# Already downloaded: oisst-avhrr-v02r01.19811204.nc
# Already downloaded: oisst-avhrr-v02r01.19811205.nc
# Already downloaded: oisst-avhrr-v02r01.19811206.nc
# Already downloaded: oisst-avhrr-v02r01.19811207.nc
# Already downloaded: oisst-avhrr-v02r01.19811203.nc
# Already downloaded: oisst-avhrr-v02r01.19811204.nc
# Already downloaded: oisst-avhrr-v02r01.19811205.nc
# Already downloaded: oisst-avhrr-v02r01.19811206.nc
# Already downloaded: oisst-avhrr-v02r01.19811207.nc
# Already downloaded: oisst-avhrr-v02r01.19811208.nc
# Already downloaded: oisst-avhrr-v02r01.19811209.nc
# Already downloaded: oisst-avhrr-v02r01.19811210.nc
# Already downloaded: oisst-avhrr-v02r01.19811211.nc
# Already downloaded: oisst-avhrr-v02r01.19811212.nc
# Already downloaded: oisst-avhrr-v02r01.19811213.nc
# Already downloaded: oisst-avhrr-v02r01.19811208.nc
# Already downloaded: oisst-avhrr-v02r01.19811209.nc
# Already downloaded: oisst-avhrr-v02r01.19811210.nc
# Already downloaded: oisst-avhrr-v02r01.19811211.nc
# Already downloaded: oisst-avhrr-v02r01.19811212.nc
# Already downloaded: oisst-avhrr-v02r01.19811213.nc
# Already downloaded: oisst-avhrr-v02r01.19811214.nc
# Already downloaded: oisst-avhrr-v02r01.19811215.nc
# Already downloaded: oisst-avhrr-v02r01.19811216.nc
# Already downloaded: oisst-avhrr-v02r01.19811217.nc
# Already downloaded: oisst-avhrr-v02r01.19811218.nc
# Already downloaded: oisst-avhrr-v02r01.19811214.nc
# Already downloaded: oisst-avhrr-v02r01.19811215.nc
# Already downloaded: oisst-avhrr-v02r01.19811216.nc
# Already downloaded: oisst-avhrr-v02r01.19811217.nc
# Already downloaded: oisst-avhrr-v02r01.19811218.nc
# Already downloaded: oisst-avhrr-v02r01.19811219.nc
# Already downloaded: oisst-avhrr-v02r01.19811220.nc
# Already downloaded: oisst-avhrr-v02r01.19811221.nc
# Already downloaded: oisst-avhrr-v02r01.19811222.nc
# Already downloaded: oisst-avhrr-v02r01.19811223.nc
# Already downloaded: oisst-avhrr-v02r01.19811224.nc
# Already downloaded: oisst-avhrr-v02r01.19811219.nc
# Already downloaded: oisst-avhrr-v02r01.19811220.nc
# Already downloaded: oisst-avhrr-v02r01.19811221.nc
# Already downloaded: oisst-avhrr-v02r01.19811222.nc
# Already downloaded: oisst-avhrr-v02r01.19811223.nc
# Already downloaded: oisst-avhrr-v02r01.19811224.nc
# Already downloaded: oisst-avhrr-v02r01.19811225.nc
# Already downloaded: oisst-avhrr-v02r01.19811226.nc
# Already downloaded: oisst-avhrr-v02r01.19811227.nc
# Already downloaded: oisst-avhrr-v02r01.19811228.nc
# Already downloaded: oisst-avhrr-v02r01.19811229.nc
# Already downloaded: oisst-avhrr-v02r01.19811225.nc
# Already downloaded: oisst-avhrr-v02r01.19811226.nc
# Already downloaded: oisst-avhrr-v02r01.19811227.nc
# Already downloaded: oisst-avhrr-v02r01.19811228.nc
# Already downloaded: oisst-avhrr-v02r01.19811229.nc
# Already downloaded: oisst-avhrr-v02r01.19811230.nc
# Already downloaded: oisst-avhrr-v02r01.19811231.nc
# Already downloaded: oisst-avhrr-v02r01.19820101.nc
# Already downloaded: oisst-avhrr-v02r01.19820102.nc
# Already downloaded: oisst-avhrr-v02r01.19820103.nc
# Already downloaded: oisst-avhrr-v02r01.19811230.nc
# Already downloaded: oisst-avhrr-v02r01.19811231.nc
# Already downloaded: oisst-avhrr-v02r01.19820101.nc
# Already downloaded: oisst-avhrr-v02r01.19820102.nc
# Already downloaded: oisst-avhrr-v02r01.19820103.nc
# Already downloaded: oisst-avhrr-v02r01.19820104.nc
# Already downloaded: oisst-avhrr-v02r01.19820105.nc
# Already downloaded: oisst-avhrr-v02r01.19820106.nc
# Already downloaded: oisst-avhrr-v02r01.19820107.nc
# Already downloaded: oisst-avhrr-v02r01.19820108.nc
# Already downloaded: oisst-avhrr-v02r01.19820104.nc
# Already downloaded: oisst-avhrr-v02r01.19820105.nc
# Already downloaded: oisst-avhrr-v02r01.19820106.nc
# Already downloaded: oisst-avhrr-v02r01.19820107.nc
# Already downloaded: oisst-avhrr-v02r01.19820108.nc
# Already downloaded: oisst-avhrr-v02r01.19820109.nc
# Already downloaded: oisst-avhrr-v02r01.19820110.nc
# Already downloaded: oisst-avhrr-v02r01.19820111.nc
# Already downloaded: oisst-avhrr-v02r01.19820112.nc
# Already downloaded: oisst-avhrr-v02r01.19820113.nc
# Already downloaded: oisst-avhrr-v02r01.19820109.nc
# Already downloaded: oisst-avhrr-v02r01.19820110.nc
# Already downloaded: oisst-avhrr-v02r01.19820111.nc
# Already downloaded: oisst-avhrr-v02r01.19820112.nc
# Already downloaded: oisst-avhrr-v02r01.19820113.nc
# Already downloaded: oisst-avhrr-v02r01.19820114.nc
# Already downloaded: oisst-avhrr-v02r01.19820115.nc
# Already downloaded: oisst-avhrr-v02r01.19820116.nc
# Already downloaded: oisst-avhrr-v02r01.19820117.nc
# Already downloaded: oisst-avhrr-v02r01.19820118.nc
# Already downloaded: oisst-avhrr-v02r01.19820119.nc
# Already downloaded: oisst-avhrr-v02r01.19820114.nc
# Already downloaded: oisst-avhrr-v02r01.19820115.nc
# Already downloaded: oisst-avhrr-v02r01.19820116.nc
# Already downloaded: oisst-avhrr-v02r01.19820117.nc
# Already downloaded: oisst-avhrr-v02r01.19820118.nc
# Already downloaded: oisst-avhrr-v02r01.19820119.nc
# Already downloaded: oisst-avhrr-v02r01.19820120.nc
# Already downloaded: oisst-avhrr-v02r01.19820121.nc
# Already downloaded: oisst-avhrr-v02r01.19820122.nc
# Already downloaded: oisst-avhrr-v02r01.19820123.nc
# Already downloaded: oisst-avhrr-v02r01.19820124.nc
# Already downloaded: oisst-avhrr-v02r01.19820125.nc
# Already downloaded: oisst-avhrr-v02r01.19820120.nc
# Already downloaded: oisst-avhrr-v02r01.19820121.nc
# Already downloaded: oisst-avhrr-v02r01.19820122.nc
# Already downloaded: oisst-avhrr-v02r01.19820123.nc
# Already downloaded: oisst-avhrr-v02r01.19820124.nc
# Already downloaded: oisst-avhrr-v02r01.19820125.nc
# Already downloaded: oisst-avhrr-v02r01.19820126.nc
# Already downloaded: oisst-avhrr-v02r01.19820127.nc
# Already downloaded: oisst-avhrr-v02r01.19820128.nc
# Already downloaded: oisst-avhrr-v02r01.19820129.nc
# Already downloaded: oisst-avhrr-v02r01.19820130.nc
# Already downloaded: oisst-avhrr-v02r01.19820131.nc
# Already downloaded: oisst-avhrr-v02r01.19820126.nc
# Already downloaded: oisst-avhrr-v02r01.19820127.nc
# Already downloaded: oisst-avhrr-v02r01.19820128.nc
# Already downloaded: oisst-avhrr-v02r01.19820129.nc
# Already downloaded: oisst-avhrr-v02r01.19820130.nc
# Already downloaded: oisst-avhrr-v02r01.19820131.nc
# Already downloaded: oisst-avhrr-v02r01.19820201.nc
# Already downloaded: oisst-avhrr-v02r01.19820202.nc
# Already downloaded: oisst-avhrr-v02r01.19820203.nc
# Already downloaded: oisst-avhrr-v02r01.19820204.nc
# Already downloaded: oisst-avhrr-v02r01.19820205.nc
# Already downloaded: oisst-avhrr-v02r01.19820201.nc
# Already downloaded: oisst-avhrr-v02r01.19820202.nc
# Already downloaded: oisst-avhrr-v02r01.19820203.nc
# Already downloaded: oisst-avhrr-v02r01.19820204.nc
# Already downloaded: oisst-avhrr-v02r01.19820205.nc
# Already downloaded: oisst-avhrr-v02r01.19820206.nc
# Already downloaded: oisst-avhrr-v02r01.19820207.nc
# Already downloaded: oisst-avhrr-v02r01.19820208.nc
# Already downloaded: oisst-avhrr-v02r01.19820209.nc
# Already downloaded: oisst-avhrr-v02r01.19820210.nc
# Already downloaded: oisst-avhrr-v02r01.19820206.nc
# Already downloaded: oisst-avhrr-v02r01.19820207.nc
# Already downloaded: oisst-avhrr-v02r01.19820208.nc
# Already downloaded: oisst-avhrr-v02r01.19820209.nc
# Already downloaded: oisst-avhrr-v02r01.19820210.nc
# Already downloaded: oisst-avhrr-v02r01.19820211.nc
# Already downloaded: oisst-avhrr-v02r01.19820212.nc
# Already downloaded: oisst-avhrr-v02r01.19820213.nc
# Already downloaded: oisst-avhrr-v02r01.19820214.nc
# Already downloaded: oisst-avhrr-v02r01.19820215.nc
# Already downloaded: oisst-avhrr-v02r01.19820211.nc
# Already downloaded: oisst-avhrr-v02r01.19820212.nc
# Already downloaded: oisst-avhrr-v02r01.19820213.nc
# Already downloaded: oisst-avhrr-v02r01.19820214.nc
# Already downloaded: oisst-avhrr-v02r01.19820215.nc
# Already downloaded: oisst-avhrr-v02r01.19820216.nc
# Already downloaded: oisst-avhrr-v02r01.19820217.nc
# Already downloaded: oisst-avhrr-v02r01.19820218.nc
# Already downloaded: oisst-avhrr-v02r01.19820219.nc
# Already downloaded: oisst-avhrr-v02r01.19820220.nc
# Already downloaded: oisst-avhrr-v02r01.19820221.nc
# Already downloaded: oisst-avhrr-v02r01.19820216.nc
# Already downloaded: oisst-avhrr-v02r01.19820217.nc
# Already downloaded: oisst-avhrr-v02r01.19820218.nc
# Already downloaded: oisst-avhrr-v02r01.19820219.nc
# Already downloaded: oisst-avhrr-v02r01.19820220.nc
# Already downloaded: oisst-avhrr-v02r01.19820221.nc
# Already downloaded: oisst-avhrr-v02r01.19820222.nc
# Already downloaded: oisst-avhrr-v02r01.19820223.nc
# Already downloaded: oisst-avhrr-v02r01.19820224.nc
# Already downloaded: oisst-avhrr-v02r01.19820225.nc
# Already downloaded: oisst-avhrr-v02r01.19820226.nc
# Already downloaded: oisst-avhrr-v02r01.19820227.nc
# Already downloaded: oisst-avhrr-v02r01.19820222.nc
# Already downloaded: oisst-avhrr-v02r01.19820223.nc
# Already downloaded: oisst-avhrr-v02r01.19820224.nc
# Already downloaded: oisst-avhrr-v02r01.19820225.nc
# Already downloaded: oisst-avhrr-v02r01.19820226.nc
# Already downloaded: oisst-avhrr-v02r01.19820227.nc
# Already downloaded: oisst-avhrr-v02r01.19820228.nc
# Already downloaded: oisst-avhrr-v02r01.19820301.nc
# Already downloaded: oisst-avhrr-v02r01.19820302.nc
# Already downloaded: oisst-avhrr-v02r01.19820303.nc
# Already downloaded: oisst-avhrr-v02r01.19820304.nc
# Already downloaded: oisst-avhrr-v02r01.19820305.nc
# Already downloaded: oisst-avhrr-v02r01.19820228.nc
# Already downloaded: oisst-avhrr-v02r01.19820301.nc
# Already downloaded: oisst-avhrr-v02r01.19820302.nc
# Already downloaded: oisst-avhrr-v02r01.19820303.nc
# Already downloaded: oisst-avhrr-v02r01.19820304.nc
# Already downloaded: oisst-avhrr-v02r01.19820305.nc
# Already downloaded: oisst-avhrr-v02r01.19820306.nc
# Already downloaded: oisst-avhrr-v02r01.19820307.nc
# Already downloaded: oisst-avhrr-v02r01.19820308.nc
# Already downloaded: oisst-avhrr-v02r01.19820309.nc
# Already downloaded: oisst-avhrr-v02r01.19820310.nc
# Already downloaded: oisst-avhrr-v02r01.19820311.nc
# Already downloaded: oisst-avhrr-v02r01.19820306.nc
# Already downloaded: oisst-avhrr-v02r01.19820307.nc
# Already downloaded: oisst-avhrr-v02r01.19820308.nc
# Already downloaded: oisst-avhrr-v02r01.19820309.nc
# Already downloaded: oisst-avhrr-v02r01.19820310.nc
# Already downloaded: oisst-avhrr-v02r01.19820311.nc
# Already downloaded: oisst-avhrr-v02r01.19820312.nc
# Already downloaded: oisst-avhrr-v02r01.19820313.nc
# Already downloaded: oisst-avhrr-v02r01.19820314.nc
# Already downloaded: oisst-avhrr-v02r01.19820315.nc
# Already downloaded: oisst-avhrr-v02r01.19820316.nc
# Already downloaded: oisst-avhrr-v02r01.19820312.nc
# Already downloaded: oisst-avhrr-v02r01.19820313.nc
# Already downloaded: oisst-avhrr-v02r01.19820314.nc
# Already downloaded: oisst-avhrr-v02r01.19820315.nc
# Already downloaded: oisst-avhrr-v02r01.19820316.nc
# Already downloaded: oisst-avhrr-v02r01.19820317.nc
# Already downloaded: oisst-avhrr-v02r01.19820318.nc
# Already downloaded: oisst-avhrr-v02r01.19820319.nc
# Already downloaded: oisst-avhrr-v02r01.19820320.nc
# Already downloaded: oisst-avhrr-v02r01.19820321.nc
# Already downloaded: oisst-avhrr-v02r01.19820322.nc
# Already downloaded: oisst-avhrr-v02r01.19820317.nc
# Already downloaded: oisst-avhrr-v02r01.19820318.nc
# Already downloaded: oisst-avhrr-v02r01.19820319.nc
# Already downloaded: oisst-avhrr-v02r01.19820320.nc
# Already downloaded: oisst-avhrr-v02r01.19820321.nc
# Already downloaded: oisst-avhrr-v02r01.19820322.nc
# Already downloaded: oisst-avhrr-v02r01.19820323.nc
# Already downloaded: oisst-avhrr-v02r01.19820324.nc
# Already downloaded: oisst-avhrr-v02r01.19820325.nc
# Already downloaded: oisst-avhrr-v02r01.19820326.nc
# Already downloaded: oisst-avhrr-v02r01.19820327.nc
# Already downloaded: oisst-avhrr-v02r01.19820323.nc
# Already downloaded: oisst-avhrr-v02r01.19820324.nc
# Already downloaded: oisst-avhrr-v02r01.19820325.nc
# Already downloaded: oisst-avhrr-v02r01.19820326.nc
# Already downloaded: oisst-avhrr-v02r01.19820327.nc
# Already downloaded: oisst-avhrr-v02r01.19820328.nc
# Already downloaded: oisst-avhrr-v02r01.19820329.nc
# Already downloaded: oisst-avhrr-v02r01.19820330.nc
# Already downloaded: oisst-avhrr-v02r01.19820331.nc
# Already downloaded: oisst-avhrr-v02r01.19820401.nc
# Already downloaded: oisst-avhrr-v02r01.19820328.nc
# Already downloaded: oisst-avhrr-v02r01.19820329.nc
# Already downloaded: oisst-avhrr-v02r01.19820330.nc
# Already downloaded: oisst-avhrr-v02r01.19820331.nc
# Already downloaded: oisst-avhrr-v02r01.19820401.nc
# Already downloaded: oisst-avhrr-v02r01.19820402.nc
# Already downloaded: oisst-avhrr-v02r01.19820403.nc
# Already downloaded: oisst-avhrr-v02r01.19820404.nc
# Already downloaded: oisst-avhrr-v02r01.19820405.nc
# Already downloaded: oisst-avhrr-v02r01.19820406.nc
# Already downloaded: oisst-avhrr-v02r01.19820402.nc
# Already downloaded: oisst-avhrr-v02r01.19820403.nc
# Already downloaded: oisst-avhrr-v02r01.19820404.nc
# Already downloaded: oisst-avhrr-v02r01.19820405.nc
# Already downloaded: oisst-avhrr-v02r01.19820406.nc
# Already downloaded: oisst-avhrr-v02r01.19820407.nc
# Already downloaded: oisst-avhrr-v02r01.19820408.nc
# Already downloaded: oisst-avhrr-v02r01.19820409.nc
# Already downloaded: oisst-avhrr-v02r01.19820410.nc
# Already downloaded: oisst-avhrr-v02r01.19820411.nc
# Already downloaded: oisst-avhrr-v02r01.19820412.nc
# Already downloaded: oisst-avhrr-v02r01.19820407.nc
# Already downloaded: oisst-avhrr-v02r01.19820408.nc
# Already downloaded: oisst-avhrr-v02r01.19820409.nc
# Already downloaded: oisst-avhrr-v02r01.19820410.nc
# Already downloaded: oisst-avhrr-v02r01.19820411.nc
# Already downloaded: oisst-avhrr-v02r01.19820412.nc
# Already downloaded: oisst-avhrr-v02r01.19820413.nc
# Already downloaded: oisst-avhrr-v02r01.19820414.nc
# Already downloaded: oisst-avhrr-v02r01.19820415.nc
# Already downloaded: oisst-avhrr-v02r01.19820416.nc
# Already downloaded: oisst-avhrr-v02r01.19820417.nc
# Already downloaded: oisst-avhrr-v02r01.19820413.nc
# Already downloaded: oisst-avhrr-v02r01.19820414.nc
# Already downloaded: oisst-avhrr-v02r01.19820415.nc
# Already downloaded: oisst-avhrr-v02r01.19820416.nc
# Already downloaded: oisst-avhrr-v02r01.19820417.nc
# Already downloaded: oisst-avhrr-v02r01.19820418.nc
# Already downloaded: oisst-avhrr-v02r01.19820419.nc
# Already downloaded: oisst-avhrr-v02r01.19820420.nc
# Already downloaded: oisst-avhrr-v02r01.19820421.nc
# Already downloaded: oisst-avhrr-v02r01.19820422.nc
# Already downloaded: oisst-avhrr-v02r01.19820423.nc
# Already downloaded: oisst-avhrr-v02r01.19820418.nc
# Already downloaded: oisst-avhrr-v02r01.19820419.nc
# Already downloaded: oisst-avhrr-v02r01.19820420.nc
# Already downloaded: oisst-avhrr-v02r01.19820421.nc
# Already downloaded: oisst-avhrr-v02r01.19820422.nc
# Already downloaded: oisst-avhrr-v02r01.19820423.nc
# Already downloaded: oisst-avhrr-v02r01.19820424.nc
# Already downloaded: oisst-avhrr-v02r01.19820425.nc
# Already downloaded: oisst-avhrr-v02r01.19820426.nc
# Already downloaded: oisst-avhrr-v02r01.19820427.nc
# Already downloaded: oisst-avhrr-v02r01.19820428.nc
# Already downloaded: oisst-avhrr-v02r01.19820429.nc
# Already downloaded: oisst-avhrr-v02r01.19820424.nc
# Already downloaded: oisst-avhrr-v02r01.19820425.nc
# Already downloaded: oisst-avhrr-v02r01.19820426.nc
# Already downloaded: oisst-avhrr-v02r01.19820427.nc
# Already downloaded: oisst-avhrr-v02r01.19820428.nc
# Already downloaded: oisst-avhrr-v02r01.19820429.nc
# Already downloaded: oisst-avhrr-v02r01.19820430.nc
# Already downloaded: oisst-avhrr-v02r01.19820501.nc
# Already downloaded: oisst-avhrr-v02r01.19820502.nc
# Already downloaded: oisst-avhrr-v02r01.19820503.nc
# Already downloaded: oisst-avhrr-v02r01.19820504.nc
# Already downloaded: oisst-avhrr-v02r01.19820430.nc
# Already downloaded: oisst-avhrr-v02r01.19820501.nc
# Already downloaded: oisst-avhrr-v02r01.19820502.nc
# Already downloaded: oisst-avhrr-v02r01.19820503.nc
# Already downloaded: oisst-avhrr-v02r01.19820504.nc
# Already downloaded: oisst-avhrr-v02r01.19820505.nc
# Already downloaded: oisst-avhrr-v02r01.19820506.nc
# Already downloaded: oisst-avhrr-v02r01.19820507.nc
# Already downloaded: oisst-avhrr-v02r01.19820508.nc
# Already downloaded: oisst-avhrr-v02r01.19820509.nc
# Already downloaded: oisst-avhrr-v02r01.19820505.nc
# Already downloaded: oisst-avhrr-v02r01.19820506.nc
# Already downloaded: oisst-avhrr-v02r01.19820507.nc
# Already downloaded: oisst-avhrr-v02r01.19820508.nc
# Already downloaded: oisst-avhrr-v02r01.19820509.nc
# Already downloaded: oisst-avhrr-v02r01.19820510.nc
# Already downloaded: oisst-avhrr-v02r01.19820511.nc
# Already downloaded: oisst-avhrr-v02r01.19820512.nc
# Already downloaded: oisst-avhrr-v02r01.19820513.nc
# Already downloaded: oisst-avhrr-v02r01.19820514.nc
# Already downloaded: oisst-avhrr-v02r01.19820515.nc
# Already downloaded: oisst-avhrr-v02r01.19820510.nc
# Already downloaded: oisst-avhrr-v02r01.19820511.nc
# Already downloaded: oisst-avhrr-v02r01.19820512.nc
# Already downloaded: oisst-avhrr-v02r01.19820513.nc
# Already downloaded: oisst-avhrr-v02r01.19820514.nc
# Already downloaded: oisst-avhrr-v02r01.19820515.nc
# Already downloaded: oisst-avhrr-v02r01.19820516.nc
# Already downloaded: oisst-avhrr-v02r01.19820517.nc
# Already downloaded: oisst-avhrr-v02r01.19820518.nc
# Already downloaded: oisst-avhrr-v02r01.19820519.nc
# Already downloaded: oisst-avhrr-v02r01.19820520.nc
# Already downloaded: oisst-avhrr-v02r01.19820516.nc
# Already downloaded: oisst-avhrr-v02r01.19820517.nc
# Already downloaded: oisst-avhrr-v02r01.19820518.nc
# Already downloaded: oisst-avhrr-v02r01.19820519.nc
# Already downloaded: oisst-avhrr-v02r01.19820520.nc
# Already downloaded: oisst-avhrr-v02r01.19820521.nc
# Already downloaded: oisst-avhrr-v02r01.19820522.nc
# Already downloaded: oisst-avhrr-v02r01.19820523.nc
# Already downloaded: oisst-avhrr-v02r01.19820524.nc
# Already downloaded: oisst-avhrr-v02r01.19820525.nc
# Already downloaded: oisst-avhrr-v02r01.19820521.nc
# Already downloaded: oisst-avhrr-v02r01.19820522.nc
# Already downloaded: oisst-avhrr-v02r01.19820523.nc
# Already downloaded: oisst-avhrr-v02r01.19820524.nc
# Already downloaded: oisst-avhrr-v02r01.19820525.nc
# Already downloaded: oisst-avhrr-v02r01.19820526.nc
# Already downloaded: oisst-avhrr-v02r01.19820527.nc
# Already downloaded: oisst-avhrr-v02r01.19820528.nc
# Already downloaded: oisst-avhrr-v02r01.19820529.nc
# Already downloaded: oisst-avhrr-v02r01.19820530.nc
# Already downloaded: oisst-avhrr-v02r01.19820526.nc
# Already downloaded: oisst-avhrr-v02r01.19820527.nc
# Already downloaded: oisst-avhrr-v02r01.19820528.nc
# Already downloaded: oisst-avhrr-v02r01.19820529.nc
# Already downloaded: oisst-avhrr-v02r01.19820530.nc
# Already downloaded: oisst-avhrr-v02r01.19820531.nc
# Already downloaded: oisst-avhrr-v02r01.19820601.nc
# Already downloaded: oisst-avhrr-v02r01.19820602.nc
# Already downloaded: oisst-avhrr-v02r01.19820603.nc
# Already downloaded: oisst-avhrr-v02r01.19820604.nc
# Already downloaded: oisst-avhrr-v02r01.19820531.nc
# Already downloaded: oisst-avhrr-v02r01.19820601.nc
# Already downloaded: oisst-avhrr-v02r01.19820602.nc
# Already downloaded: oisst-avhrr-v02r01.19820603.nc
# Already downloaded: oisst-avhrr-v02r01.19820604.nc
# Already downloaded: oisst-avhrr-v02r01.19820605.nc
# Already downloaded: oisst-avhrr-v02r01.19820606.nc
# Already downloaded: oisst-avhrr-v02r01.19820607.nc
# Already downloaded: oisst-avhrr-v02r01.19820608.nc
# Already downloaded: oisst-avhrr-v02r01.19820609.nc
# Already downloaded: oisst-avhrr-v02r01.19820610.nc
# Already downloaded: oisst-avhrr-v02r01.19820605.nc
# Already downloaded: oisst-avhrr-v02r01.19820606.nc
# Already downloaded: oisst-avhrr-v02r01.19820607.nc
# Already downloaded: oisst-avhrr-v02r01.19820608.nc
# Already downloaded: oisst-avhrr-v02r01.19820609.nc
# Already downloaded: oisst-avhrr-v02r01.19820610.nc
# Already downloaded: oisst-avhrr-v02r01.19820611.nc
# Already downloaded: oisst-avhrr-v02r01.19820612.nc
# Already downloaded: oisst-avhrr-v02r01.19820613.nc
# Already downloaded: oisst-avhrr-v02r01.19820614.nc
# Already downloaded: oisst-avhrr-v02r01.19820615.nc
# Already downloaded: oisst-avhrr-v02r01.19820611.nc
# Already downloaded: oisst-avhrr-v02r01.19820612.nc
# Already downloaded: oisst-avhrr-v02r01.19820613.nc
# Already downloaded: oisst-avhrr-v02r01.19820614.nc
# Already downloaded: oisst-avhrr-v02r01.19820615.nc
# Already downloaded: oisst-avhrr-v02r01.19820616.nc
# Already downloaded: oisst-avhrr-v02r01.19820617.nc
# Already downloaded: oisst-avhrr-v02r01.19820618.nc
# Already downloaded: oisst-avhrr-v02r01.19820619.nc
# Already downloaded: oisst-avhrr-v02r01.19820620.nc
# Already downloaded: oisst-avhrr-v02r01.19820616.nc
# Already downloaded: oisst-avhrr-v02r01.19820617.nc
# Already downloaded: oisst-avhrr-v02r01.19820618.nc
# Already downloaded: oisst-avhrr-v02r01.19820619.nc
# Already downloaded: oisst-avhrr-v02r01.19820620.nc
# Already downloaded: oisst-avhrr-v02r01.19820621.nc
# Already downloaded: oisst-avhrr-v02r01.19820622.nc
# Already downloaded: oisst-avhrr-v02r01.19820623.nc
# Already downloaded: oisst-avhrr-v02r01.19820624.nc
# Already downloaded: oisst-avhrr-v02r01.19820625.nc
# Already downloaded: oisst-avhrr-v02r01.19820626.nc
# Already downloaded: oisst-avhrr-v02r01.19820621.nc
# Already downloaded: oisst-avhrr-v02r01.19820622.nc
# Already downloaded: oisst-avhrr-v02r01.19820623.nc
# Already downloaded: oisst-avhrr-v02r01.19820624.nc
# Already downloaded: oisst-avhrr-v02r01.19820625.nc
# Already downloaded: oisst-avhrr-v02r01.19820626.nc
# Already downloaded: oisst-avhrr-v02r01.19820627.nc
# Already downloaded: oisst-avhrr-v02r01.19820628.nc
# Already downloaded: oisst-avhrr-v02r01.19820629.nc
# Already downloaded: oisst-avhrr-v02r01.19820630.nc
# Already downloaded: oisst-avhrr-v02r01.19820701.nc
# Already downloaded: oisst-avhrr-v02r01.19820702.nc
# Already downloaded: oisst-avhrr-v02r01.19820627.nc
# Already downloaded: oisst-avhrr-v02r01.19820628.nc
# Already downloaded: oisst-avhrr-v02r01.19820629.nc
# Already downloaded: oisst-avhrr-v02r01.19820630.nc
# Already downloaded: oisst-avhrr-v02r01.19820701.nc
# Already downloaded: oisst-avhrr-v02r01.19820702.nc
# Already downloaded: oisst-avhrr-v02r01.19820703.nc
# Already downloaded: oisst-avhrr-v02r01.19820704.nc
# Already downloaded: oisst-avhrr-v02r01.19820705.nc
# Already downloaded: oisst-avhrr-v02r01.19820706.nc
# Already downloaded: oisst-avhrr-v02r01.19820707.nc
# Already downloaded: oisst-avhrr-v02r01.19820703.nc
# Already downloaded: oisst-avhrr-v02r01.19820704.nc
# Already downloaded: oisst-avhrr-v02r01.19820705.nc
# Already downloaded: oisst-avhrr-v02r01.19820706.nc
# Already downloaded: oisst-avhrr-v02r01.19820707.nc
# Already downloaded: oisst-avhrr-v02r01.19820708.nc
# Already downloaded: oisst-avhrr-v02r01.19820709.nc
# Already downloaded: oisst-avhrr-v02r01.19820710.nc
# Already downloaded: oisst-avhrr-v02r01.19820711.nc
# Already downloaded: oisst-avhrr-v02r01.19820712.nc
# Already downloaded: oisst-avhrr-v02r01.19820708.nc
# Already downloaded: oisst-avhrr-v02r01.19820709.nc
# Already downloaded: oisst-avhrr-v02r01.19820710.nc
# Already downloaded: oisst-avhrr-v02r01.19820711.nc
# Already downloaded: oisst-avhrr-v02r01.19820712.nc
# Already downloaded: oisst-avhrr-v02r01.19820713.nc
# Already downloaded: oisst-avhrr-v02r01.19820714.nc
# Already downloaded: oisst-avhrr-v02r01.19820715.nc
# Already downloaded: oisst-avhrr-v02r01.19820716.nc
# Already downloaded: oisst-avhrr-v02r01.19820717.nc
# Already downloaded: oisst-avhrr-v02r01.19820713.nc
# Already downloaded: oisst-avhrr-v02r01.19820714.nc
# Already downloaded: oisst-avhrr-v02r01.19820715.nc
# Already downloaded: oisst-avhrr-v02r01.19820716.nc
# Already downloaded: oisst-avhrr-v02r01.19820717.nc
# Already downloaded: oisst-avhrr-v02r01.19820718.nc
# Already downloaded: oisst-avhrr-v02r01.19820719.nc
# Already downloaded: oisst-avhrr-v02r01.19820720.nc
# Already downloaded: oisst-avhrr-v02r01.19820721.nc
# Already downloaded: oisst-avhrr-v02r01.19820722.nc
# Already downloaded: oisst-avhrr-v02r01.19820718.nc
# Already downloaded: oisst-avhrr-v02r01.19820719.nc
# Already downloaded: oisst-avhrr-v02r01.19820720.nc
# Already downloaded: oisst-avhrr-v02r01.19820721.nc
# Already downloaded: oisst-avhrr-v02r01.19820722.nc
# Already downloaded: oisst-avhrr-v02r01.19820723.nc
# Already downloaded: oisst-avhrr-v02r01.19820724.nc
# Already downloaded: oisst-avhrr-v02r01.19820725.nc
# Already downloaded: oisst-avhrr-v02r01.19820726.nc
# Already downloaded: oisst-avhrr-v02r01.19820727.nc
# Already downloaded: oisst-avhrr-v02r01.19820723.nc
# Already downloaded: oisst-avhrr-v02r01.19820724.nc
# Already downloaded: oisst-avhrr-v02r01.19820725.nc
# Already downloaded: oisst-avhrr-v02r01.19820726.nc
# Already downloaded: oisst-avhrr-v02r01.19820727.nc
# Already downloaded: oisst-avhrr-v02r01.19820728.nc
# Already downloaded: oisst-avhrr-v02r01.19820729.nc
# Already downloaded: oisst-avhrr-v02r01.19820730.nc
# Already downloaded: oisst-avhrr-v02r01.19820731.nc
# Already downloaded: oisst-avhrr-v02r01.19820801.nc
# Already downloaded: oisst-avhrr-v02r01.19820728.nc
# Already downloaded: oisst-avhrr-v02r01.19820729.nc
# Already downloaded: oisst-avhrr-v02r01.19820730.nc
# Already downloaded: oisst-avhrr-v02r01.19820731.nc
# Already downloaded: oisst-avhrr-v02r01.19820801.nc
# Already downloaded: oisst-avhrr-v02r01.19820802.nc
# Already downloaded: oisst-avhrr-v02r01.19820803.nc
# Already downloaded: oisst-avhrr-v02r01.19820804.nc
# Already downloaded: oisst-avhrr-v02r01.19820805.nc
# Already downloaded: oisst-avhrr-v02r01.19820806.nc
# Already downloaded: oisst-avhrr-v02r01.19820802.nc
# Already downloaded: oisst-avhrr-v02r01.19820803.nc
# Already downloaded: oisst-avhrr-v02r01.19820804.nc
# Already downloaded: oisst-avhrr-v02r01.19820805.nc
# Already downloaded: oisst-avhrr-v02r01.19820806.nc
# Already downloaded: oisst-avhrr-v02r01.19820807.nc
# Already downloaded: oisst-avhrr-v02r01.19820808.nc
# Already downloaded: oisst-avhrr-v02r01.19820809.nc
# Already downloaded: oisst-avhrr-v02r01.19820810.nc
# Already downloaded: oisst-avhrr-v02r01.19820811.nc
# Already downloaded: oisst-avhrr-v02r01.19820812.nc
# Already downloaded: oisst-avhrr-v02r01.19820807.nc
# Already downloaded: oisst-avhrr-v02r01.19820808.nc
# Already downloaded: oisst-avhrr-v02r01.19820809.nc
# Already downloaded: oisst-avhrr-v02r01.19820810.nc
# Already downloaded: oisst-avhrr-v02r01.19820811.nc
# Already downloaded: oisst-avhrr-v02r01.19820812.nc
# Already downloaded: oisst-avhrr-v02r01.19820813.nc
# Already downloaded: oisst-avhrr-v02r01.19820814.nc
# Already downloaded: oisst-avhrr-v02r01.19820815.nc
# Already downloaded: oisst-avhrr-v02r01.19820816.nc
# Already downloaded: oisst-avhrr-v02r01.19820817.nc
# Already downloaded: oisst-avhrr-v02r01.19820813.nc
# Already downloaded: oisst-avhrr-v02r01.19820814.nc
# Already downloaded: oisst-avhrr-v02r01.19820815.nc
# Already downloaded: oisst-avhrr-v02r01.19820816.nc
# Already downloaded: oisst-avhrr-v02r01.19820817.nc
# Already downloaded: oisst-avhrr-v02r01.19820818.nc
# Already downloaded: oisst-avhrr-v02r01.19820819.nc
# Already downloaded: oisst-avhrr-v02r01.19820820.nc
# Already downloaded: oisst-avhrr-v02r01.19820821.nc
# Already downloaded: oisst-avhrr-v02r01.19820822.nc
# Already downloaded: oisst-avhrr-v02r01.19820818.nc
# Already downloaded: oisst-avhrr-v02r01.19820819.nc
# Already downloaded: oisst-avhrr-v02r01.19820820.nc
# Already downloaded: oisst-avhrr-v02r01.19820821.nc
# Already downloaded: oisst-avhrr-v02r01.19820822.nc
# Already downloaded: oisst-avhrr-v02r01.19820823.nc
# Already downloaded: oisst-avhrr-v02r01.19820824.nc
# Already downloaded: oisst-avhrr-v02r01.19820825.nc
# Already downloaded: oisst-avhrr-v02r01.19820826.nc
# Already downloaded: oisst-avhrr-v02r01.19820827.nc
# Already downloaded: oisst-avhrr-v02r01.19820823.nc
# Already downloaded: oisst-avhrr-v02r01.19820824.nc
# Already downloaded: oisst-avhrr-v02r01.19820825.nc
# Already downloaded: oisst-avhrr-v02r01.19820826.nc
# Already downloaded: oisst-avhrr-v02r01.19820827.nc
# Already downloaded: oisst-avhrr-v02r01.19820828.nc
# Already downloaded: oisst-avhrr-v02r01.19820829.nc
# Already downloaded: oisst-avhrr-v02r01.19820830.nc
# Already downloaded: oisst-avhrr-v02r01.19820831.nc
# Already downloaded: oisst-avhrr-v02r01.19820901.nc
# Already downloaded: oisst-avhrr-v02r01.19820828.nc
# Already downloaded: oisst-avhrr-v02r01.19820829.nc
# Already downloaded: oisst-avhrr-v02r01.19820830.nc
# Already downloaded: oisst-avhrr-v02r01.19820831.nc
# Already downloaded: oisst-avhrr-v02r01.19820901.nc
# Already downloaded: oisst-avhrr-v02r01.19820902.nc
# Already downloaded: oisst-avhrr-v02r01.19820903.nc
# Already downloaded: oisst-avhrr-v02r01.19820904.nc
# Already downloaded: oisst-avhrr-v02r01.19820905.nc
# Already downloaded: oisst-avhrr-v02r01.19820906.nc
# Already downloaded: oisst-avhrr-v02r01.19820907.nc
# Already downloaded: oisst-avhrr-v02r01.19820902.nc
# Already downloaded: oisst-avhrr-v02r01.19820903.nc
# Already downloaded: oisst-avhrr-v02r01.19820904.nc
# Already downloaded: oisst-avhrr-v02r01.19820905.nc
# Already downloaded: oisst-avhrr-v02r01.19820906.nc
# Already downloaded: oisst-avhrr-v02r01.19820907.nc
# Already downloaded: oisst-avhrr-v02r01.19820908.nc
# Already downloaded: oisst-avhrr-v02r01.19820909.nc
# Already downloaded: oisst-avhrr-v02r01.19820910.nc
# Already downloaded: oisst-avhrr-v02r01.19820911.nc
# Already downloaded: oisst-avhrr-v02r01.19820912.nc
# Already downloaded: oisst-avhrr-v02r01.19820913.nc
# Already downloaded: oisst-avhrr-v02r01.19820908.nc
# Already downloaded: oisst-avhrr-v02r01.19820909.nc
# Already downloaded: oisst-avhrr-v02r01.19820910.nc
# Already downloaded: oisst-avhrr-v02r01.19820911.nc
# Already downloaded: oisst-avhrr-v02r01.19820912.nc
# Already downloaded: oisst-avhrr-v02r01.19820913.nc
# Already downloaded: oisst-avhrr-v02r01.19820914.nc
# Already downloaded: oisst-avhrr-v02r01.19820915.nc
# Already downloaded: oisst-avhrr-v02r01.19820916.nc
# Already downloaded: oisst-avhrr-v02r01.19820917.nc
# Already downloaded: oisst-avhrr-v02r01.19820918.nc
# Already downloaded: oisst-avhrr-v02r01.19820914.nc
# Already downloaded: oisst-avhrr-v02r01.19820915.nc
# Already downloaded: oisst-avhrr-v02r01.19820916.nc
# Already downloaded: oisst-avhrr-v02r01.19820917.nc
# Already downloaded: oisst-avhrr-v02r01.19820918.nc
# Already downloaded: oisst-avhrr-v02r01.19820919.nc
# Already downloaded: oisst-avhrr-v02r01.19820920.nc
# Already downloaded: oisst-avhrr-v02r01.19820921.nc
# Already downloaded: oisst-avhrr-v02r01.19820922.nc
# Already downloaded: oisst-avhrr-v02r01.19820923.nc
# Already downloaded: oisst-avhrr-v02r01.19820919.nc
# Already downloaded: oisst-avhrr-v02r01.19820920.nc
# Already downloaded: oisst-avhrr-v02r01.19820921.nc
# Already downloaded: oisst-avhrr-v02r01.19820922.nc
# Already downloaded: oisst-avhrr-v02r01.19820923.nc
# Already downloaded: oisst-avhrr-v02r01.19820924.nc
# Already downloaded: oisst-avhrr-v02r01.19820925.nc
# Already downloaded: oisst-avhrr-v02r01.19820926.nc
# Already downloaded: oisst-avhrr-v02r01.19820927.nc
# Already downloaded: oisst-avhrr-v02r01.19820928.nc
# Already downloaded: oisst-avhrr-v02r01.19820929.nc
# Already downloaded: oisst-avhrr-v02r01.19820924.nc
# Already downloaded: oisst-avhrr-v02r01.19820925.nc
# Already downloaded: oisst-avhrr-v02r01.19820926.nc
# Already downloaded: oisst-avhrr-v02r01.19820927.nc
# Already downloaded: oisst-avhrr-v02r01.19820928.nc
# Already downloaded: oisst-avhrr-v02r01.19820929.nc
# Already downloaded: oisst-avhrr-v02r01.19820930.nc
# Already downloaded: oisst-avhrr-v02r01.19821001.nc
# Already downloaded: oisst-avhrr-v02r01.19821002.nc
# Already downloaded: oisst-avhrr-v02r01.19821003.nc
# Already downloaded: oisst-avhrr-v02r01.19821004.nc
# Already downloaded: oisst-avhrr-v02r01.19820930.nc
# Already downloaded: oisst-avhrr-v02r01.19821001.nc
# Already downloaded: oisst-avhrr-v02r01.19821002.nc
# Already downloaded: oisst-avhrr-v02r01.19821003.nc
# Already downloaded: oisst-avhrr-v02r01.19821004.nc
# Already downloaded: oisst-avhrr-v02r01.19821005.nc
# Already downloaded: oisst-avhrr-v02r01.19821006.nc
# Already downloaded: oisst-avhrr-v02r01.19821007.nc
# Already downloaded: oisst-avhrr-v02r01.19821008.nc
# Already downloaded: oisst-avhrr-v02r01.19821009.nc
# Already downloaded: oisst-avhrr-v02r01.19821005.nc
# Already downloaded: oisst-avhrr-v02r01.19821006.nc
# Already downloaded: oisst-avhrr-v02r01.19821007.nc
# Already downloaded: oisst-avhrr-v02r01.19821008.nc
# Already downloaded: oisst-avhrr-v02r01.19821009.nc
# Already downloaded: oisst-avhrr-v02r01.19821010.nc
# Already downloaded: oisst-avhrr-v02r01.19821011.nc
# Already downloaded: oisst-avhrr-v02r01.19821012.nc
# Already downloaded: oisst-avhrr-v02r01.19821013.nc
# Already downloaded: oisst-avhrr-v02r01.19821014.nc
# Already downloaded: oisst-avhrr-v02r01.19821015.nc
# Already downloaded: oisst-avhrr-v02r01.19821010.nc
# Already downloaded: oisst-avhrr-v02r01.19821011.nc
# Already downloaded: oisst-avhrr-v02r01.19821012.nc
# Already downloaded: oisst-avhrr-v02r01.19821013.nc
# Already downloaded: oisst-avhrr-v02r01.19821014.nc
# Already downloaded: oisst-avhrr-v02r01.19821015.nc
# Already downloaded: oisst-avhrr-v02r01.19821016.nc
# Already downloaded: oisst-avhrr-v02r01.19821017.nc
# Already downloaded: oisst-avhrr-v02r01.19821018.nc
# Already downloaded: oisst-avhrr-v02r01.19821019.nc
# Already downloaded: oisst-avhrr-v02r01.19821020.nc
# Already downloaded: oisst-avhrr-v02r01.19821021.nc
# Already downloaded: oisst-avhrr-v02r01.19821016.nc
# Already downloaded: oisst-avhrr-v02r01.19821017.nc
# Already downloaded: oisst-avhrr-v02r01.19821018.nc
# Already downloaded: oisst-avhrr-v02r01.19821019.nc
# Already downloaded: oisst-avhrr-v02r01.19821020.nc
# Already downloaded: oisst-avhrr-v02r01.19821021.nc
# Already downloaded: oisst-avhrr-v02r01.19821022.nc
# Already downloaded: oisst-avhrr-v02r01.19821023.nc
# Already downloaded: oisst-avhrr-v02r01.19821024.nc
# Already downloaded: oisst-avhrr-v02r01.19821025.nc
# Already downloaded: oisst-avhrr-v02r01.19821026.nc
# Already downloaded: oisst-avhrr-v02r01.19821022.nc
# Already downloaded: oisst-avhrr-v02r01.19821023.nc
# Already downloaded: oisst-avhrr-v02r01.19821024.nc
# Already downloaded: oisst-avhrr-v02r01.19821025.nc
# Already downloaded: oisst-avhrr-v02r01.19821026.nc
# Already downloaded: oisst-avhrr-v02r01.19821027.nc
# Already downloaded: oisst-avhrr-v02r01.19821028.nc
# Already downloaded: oisst-avhrr-v02r01.19821029.nc
# Already downloaded: oisst-avhrr-v02r01.19821030.nc
# Already downloaded: oisst-avhrr-v02r01.19821031.nc
# Already downloaded: oisst-avhrr-v02r01.19821027.nc
# Already downloaded: oisst-avhrr-v02r01.19821028.nc
# Already downloaded: oisst-avhrr-v02r01.19821029.nc
# Already downloaded: oisst-avhrr-v02r01.19821030.nc
# Already downloaded: oisst-avhrr-v02r01.19821031.nc
# Already downloaded: oisst-avhrr-v02r01.19821101.nc
# Already downloaded: oisst-avhrr-v02r01.19821102.nc
# Already downloaded: oisst-avhrr-v02r01.19821103.nc
# Already downloaded: oisst-avhrr-v02r01.19821104.nc
# Already downloaded: oisst-avhrr-v02r01.19821105.nc
# Already downloaded: oisst-avhrr-v02r01.19821101.nc
# Already downloaded: oisst-avhrr-v02r01.19821102.nc
# Already downloaded: oisst-avhrr-v02r01.19821103.nc
# Already downloaded: oisst-avhrr-v02r01.19821104.nc
# Already downloaded: oisst-avhrr-v02r01.19821105.nc
# Already downloaded: oisst-avhrr-v02r01.19821106.nc
# Already downloaded: oisst-avhrr-v02r01.19821107.nc
# Already downloaded: oisst-avhrr-v02r01.19821108.nc
# Already downloaded: oisst-avhrr-v02r01.19821109.nc
# Already downloaded: oisst-avhrr-v02r01.19821110.nc
# Already downloaded: oisst-avhrr-v02r01.19821111.nc
# Already downloaded: oisst-avhrr-v02r01.19821106.nc
# Already downloaded: oisst-avhrr-v02r01.19821107.nc
# Already downloaded: oisst-avhrr-v02r01.19821108.nc
# Already downloaded: oisst-avhrr-v02r01.19821109.nc
# Already downloaded: oisst-avhrr-v02r01.19821110.nc
# Already downloaded: oisst-avhrr-v02r01.19821111.nc
# Already downloaded: oisst-avhrr-v02r01.19821112.nc
# Already downloaded: oisst-avhrr-v02r01.19821113.nc
# Already downloaded: oisst-avhrr-v02r01.19821114.nc
# Already downloaded: oisst-avhrr-v02r01.19821115.nc
# Already downloaded: oisst-avhrr-v02r01.19821116.nc
# Already downloaded: oisst-avhrr-v02r01.19821117.nc
# Already downloaded: oisst-avhrr-v02r01.19821112.nc
# Already downloaded: oisst-avhrr-v02r01.19821113.nc
# Already downloaded: oisst-avhrr-v02r01.19821114.nc
# Already downloaded: oisst-avhrr-v02r01.19821115.nc
# Already downloaded: oisst-avhrr-v02r01.19821116.nc
# Already downloaded: oisst-avhrr-v02r01.19821117.nc
# Already downloaded: oisst-avhrr-v02r01.19821118.nc
# Already downloaded: oisst-avhrr-v02r01.19821119.nc
# Already downloaded: oisst-avhrr-v02r01.19821120.nc
# Already downloaded: oisst-avhrr-v02r01.19821121.nc
# Already downloaded: oisst-avhrr-v02r01.19821122.nc
# Already downloaded: oisst-avhrr-v02r01.19821118.nc
# Already downloaded: oisst-avhrr-v02r01.19821119.nc
# Already downloaded: oisst-avhrr-v02r01.19821120.nc
# Already downloaded: oisst-avhrr-v02r01.19821121.nc
# Already downloaded: oisst-avhrr-v02r01.19821122.nc
# Already downloaded: oisst-avhrr-v02r01.19821123.nc
# Already downloaded: oisst-avhrr-v02r01.19821124.nc
# Already downloaded: oisst-avhrr-v02r01.19821125.nc
# Already downloaded: oisst-avhrr-v02r01.19821126.nc
# Already downloaded: oisst-avhrr-v02r01.19821127.nc
# Already downloaded: oisst-avhrr-v02r01.19821123.nc
# Already downloaded: oisst-avhrr-v02r01.19821124.nc
# Already downloaded: oisst-avhrr-v02r01.19821125.nc
# Already downloaded: oisst-avhrr-v02r01.19821126.nc
# Already downloaded: oisst-avhrr-v02r01.19821127.nc
# Already downloaded: oisst-avhrr-v02r01.19821128.nc
# Already downloaded: oisst-avhrr-v02r01.19821129.nc
# Already downloaded: oisst-avhrr-v02r01.19821130.nc
# Already downloaded: oisst-avhrr-v02r01.19821201.nc
# Already downloaded: oisst-avhrr-v02r01.19821202.nc
# Already downloaded: oisst-avhrr-v02r01.19821128.nc
# Already downloaded: oisst-avhrr-v02r01.19821129.nc
# Already downloaded: oisst-avhrr-v02r01.19821130.nc
# Already downloaded: oisst-avhrr-v02r01.19821201.nc
# Already downloaded: oisst-avhrr-v02r01.19821202.nc
# Already downloaded: oisst-avhrr-v02r01.19821203.nc
# Already downloaded: oisst-avhrr-v02r01.19821204.nc
# Already downloaded: oisst-avhrr-v02r01.19821205.nc
# Already downloaded: oisst-avhrr-v02r01.19821206.nc
# Already downloaded: oisst-avhrr-v02r01.19821207.nc
# Already downloaded: oisst-avhrr-v02r01.19821208.nc
# Already downloaded: oisst-avhrr-v02r01.19821203.nc
# Already downloaded: oisst-avhrr-v02r01.19821204.nc
# Already downloaded: oisst-avhrr-v02r01.19821205.nc
# Already downloaded: oisst-avhrr-v02r01.19821206.nc
# Already downloaded: oisst-avhrr-v02r01.19821207.nc
# Already downloaded: oisst-avhrr-v02r01.19821208.nc
# Already downloaded: oisst-avhrr-v02r01.19821209.nc
# Already downloaded: oisst-avhrr-v02r01.19821210.nc
# Already downloaded: oisst-avhrr-v02r01.19821211.nc
# Already downloaded: oisst-avhrr-v02r01.19821212.nc
# Already downloaded: oisst-avhrr-v02r01.19821213.nc
# Already downloaded: oisst-avhrr-v02r01.19821209.nc
# Already downloaded: oisst-avhrr-v02r01.19821210.nc
# Already downloaded: oisst-avhrr-v02r01.19821211.nc
# Already downloaded: oisst-avhrr-v02r01.19821212.nc
# Already downloaded: oisst-avhrr-v02r01.19821213.nc
# Already downloaded: oisst-avhrr-v02r01.19821214.nc
# Already downloaded: oisst-avhrr-v02r01.19821215.nc
# Already downloaded: oisst-avhrr-v02r01.19821216.nc
# Already downloaded: oisst-avhrr-v02r01.19821217.nc
# Already downloaded: oisst-avhrr-v02r01.19821218.nc
# Already downloaded: oisst-avhrr-v02r01.19821214.nc
# Already downloaded: oisst-avhrr-v02r01.19821215.nc
# Already downloaded: oisst-avhrr-v02r01.19821216.nc
# ...
# Already downloaded: oisst-avhrr-v02r01.19970831.nc
# Already downloaded: oisst-avhrr-v02r01.19970901.nc
# Already downloaded: oisst-avhrr-v02r01.19970902.nc
# Already downloaded: oisst-avhrr-v02r01.19970903.nc
# Already downloaded: oisst-avhrr-v02r01.19970904.nc
# Already downloaded: oisst-avhrr-v02r01.19970905.nc
# Already downloaded: oisst-avhrr-v02r01.19970906.nc
# Already downloaded: oisst-avhrr-v02r01.19970907.nc
# Already downloaded: oisst-avhrr-v02r01.19970908.nc
# Already downloaded: oisst-avhrr-v02r01.19970903.nc
# Already downloaded: oisst-avhrr-v02r01.19970904.nc
# Already downloaded: oisst-avhrr-v02r01.19970905.nc
# Already downloaded: oisst-avhrr-v02r01.19970906.nc
# Already downloaded: oisst-avhrr-v02r01.19970907.nc
# Already downloaded: oisst-avhrr-v02r01.19970908.nc
# Already downloaded: oisst-avhrr-v02r01.19970909.nc
# Already downloaded: oisst-avhrr-v02r01.19970910.nc
# Already downloaded: oisst-avhrr-v02r01.19970911.nc
# Already downloaded: oisst-avhrr-v02r01.19970912.nc
# Already downloaded: oisst-avhrr-v02r01.19970913.nc
# Already downloaded: oisst-avhrr-v02r01.19970914.nc
# Already downloaded: oisst-avhrr-v02r01.19970909.nc
# Already downloaded: oisst-avhrr-v02r01.19970910.nc
# Already downloaded: oisst-avhrr-v02r01.19970911.nc
# Already downloaded: oisst-avhrr-v02r01.19970912.nc
# Already downloaded: oisst-avhrr-v02r01.19970913.nc
# Already downloaded: oisst-avhrr-v02r01.19970914.nc
# Already downloaded: oisst-avhrr-v02r01.19970915.nc
# Already downloaded: oisst-avhrr-v02r01.19970916.nc
# Already downloaded: oisst-avhrr-v02r01.19970917.nc
# Already downloaded: oisst-avhrr-v02r01.19970918.nc
# Already downloaded: oisst-avhrr-v02r01.19970919.nc
# Already downloaded: oisst-avhrr-v02r01.19970920.nc
# Already downloaded: oisst-avhrr-v02r01.19970915.nc
# Already downloaded: oisst-avhrr-v02r01.19970916.nc
# Already downloaded: oisst-avhrr-v02r01.19970917.nc
# Already downloaded: oisst-avhrr-v02r01.19970918.nc
# Already downloaded: oisst-avhrr-v02r01.19970919.nc
# Already downloaded: oisst-avhrr-v02r01.19970920.nc
# Already downloaded: oisst-avhrr-v02r01.19970921.nc
# Already downloaded: oisst-avhrr-v02r01.19970922.nc
# Already downloaded: oisst-avhrr-v02r01.19970923.nc
# Already downloaded: oisst-avhrr-v02r01.19970924.nc
# Already downloaded: oisst-avhrr-v02r01.19970925.nc
# Already downloaded: oisst-avhrr-v02r01.19970921.nc
# Already downloaded: oisst-avhrr-v02r01.19970922.nc
# Already downloaded: oisst-avhrr-v02r01.19970923.nc
# Already downloaded: oisst-avhrr-v02r01.19970924.nc
# Already downloaded: oisst-avhrr-v02r01.19970925.nc
# Already downloaded: oisst-avhrr-v02r01.19970926.nc
# Already downloaded: oisst-avhrr-v02r01.19970927.nc
# Already downloaded: oisst-avhrr-v02r01.19970928.nc
# Already downloaded: oisst-avhrr-v02r01.19970929.nc
# Already downloaded: oisst-avhrr-v02r01.19970930.nc
# Already downloaded: oisst-avhrr-v02r01.19971001.nc
# Already downloaded: oisst-avhrr-v02r01.19970926.nc
# Already downloaded: oisst-avhrr-v02r01.19970927.nc
# Already downloaded: oisst-avhrr-v02r01.19970928.nc
# Already downloaded: oisst-avhrr-v02r01.19970929.nc
# Already downloaded: oisst-avhrr-v02r01.19970930.nc
# Already downloaded: oisst-avhrr-v02r01.19971001.nc
# Already downloaded: oisst-avhrr-v02r01.19971002.nc
# Already downloaded: oisst-avhrr-v02r01.19971003.nc
# Already downloaded: oisst-avhrr-v02r01.19971004.nc
# Already downloaded: oisst-avhrr-v02r01.19971005.nc
# Already downloaded: oisst-avhrr-v02r01.19971006.nc
# Already downloaded: oisst-avhrr-v02r01.19971007.nc
# Already downloaded: oisst-avhrr-v02r01.19971002.nc
# Already downloaded: oisst-avhrr-v02r01.19971003.nc
# Already downloaded: oisst-avhrr-v02r01.19971004.nc
# Already downloaded: oisst-avhrr-v02r01.19971005.nc
# Already downloaded: oisst-avhrr-v02r01.19971006.nc
# Already downloaded: oisst-avhrr-v02r01.19971007.nc
# Already downloaded: oisst-avhrr-v02r01.19971008.nc
# Already downloaded: oisst-avhrr-v02r01.19971009.nc
# Already downloaded: oisst-avhrr-v02r01.19971010.nc
# Already downloaded: oisst-avhrr-v02r01.19971011.nc
# Already downloaded: oisst-avhrr-v02r01.19971012.nc
# Already downloaded: oisst-avhrr-v02r01.19971013.nc
# Already downloaded: oisst-avhrr-v02r01.19971008.nc
# Already downloaded: oisst-avhrr-v02r01.19971009.nc
# Already downloaded: oisst-avhrr-v02r01.19971010.nc
# Already downloaded: oisst-avhrr-v02r01.19971011.nc
# Already downloaded: oisst-avhrr-v02r01.19971012.nc
# Already downloaded: oisst-avhrr-v02r01.19971013.nc
# Already downloaded: oisst-avhrr-v02r01.19971014.nc
# Already downloaded: oisst-avhrr-v02r01.19971015.nc
# Already downloaded: oisst-avhrr-v02r01.19971016.nc
# Already downloaded: oisst-avhrr-v02r01.19971017.nc
# Already downloaded: oisst-avhrr-v02r01.19971018.nc
# Already downloaded: oisst-avhrr-v02r01.19971014.nc
# Already downloaded: oisst-avhrr-v02r01.19971015.nc
# Already downloaded: oisst-avhrr-v02r01.19971016.nc
# Already downloaded: oisst-avhrr-v02r01.19971017.nc
# Already downloaded: oisst-avhrr-v02r01.19971018.nc
# Already downloaded: oisst-avhrr-v02r01.19971019.nc
# Already downloaded: oisst-avhrr-v02r01.19971020.nc
# Already downloaded: oisst-avhrr-v02r01.19971021.nc
# Already downloaded: oisst-avhrr-v02r01.19971022.nc
# Already downloaded: oisst-avhrr-v02r01.19971023.nc
# Already downloaded: oisst-avhrr-v02r01.19971019.nc
# Already downloaded: oisst-avhrr-v02r01.19971020.nc
# Already downloaded: oisst-avhrr-v02r01.19971021.nc
# Already downloaded: oisst-avhrr-v02r01.19971022.nc
# Already downloaded: oisst-avhrr-v02r01.19971023.nc
# Already downloaded: oisst-avhrr-v02r01.19971024.nc
# Already downloaded: oisst-avhrr-v02r01.19971025.nc
# Already downloaded: oisst-avhrr-v02r01.19971026.nc
# Already downloaded: oisst-avhrr-v02r01.19971027.nc
# Already downloaded: oisst-avhrr-v02r01.19971028.nc
# Already downloaded: oisst-avhrr-v02r01.19971029.nc
# Already downloaded: oisst-avhrr-v02r01.19971024.nc
# Already downloaded: oisst-avhrr-v02r01.19971025.nc
# Already downloaded: oisst-avhrr-v02r01.19971026.nc
# Already downloaded: oisst-avhrr-v02r01.19971027.nc
# Already downloaded: oisst-avhrr-v02r01.19971028.nc
# Already downloaded: oisst-avhrr-v02r01.19971029.nc
# Already downloaded: oisst-avhrr-v02r01.19971030.nc
# Already downloaded: oisst-avhrr-v02r01.19971031.nc
# Already downloaded: oisst-avhrr-v02r01.19971101.nc
# Already downloaded: oisst-avhrr-v02r01.19971102.nc
# Already downloaded: oisst-avhrr-v02r01.19971103.nc
# Already downloaded: oisst-avhrr-v02r01.19971104.nc
# Already downloaded: oisst-avhrr-v02r01.19971030.nc
# Already downloaded: oisst-avhrr-v02r01.19971031.nc
# Already downloaded: oisst-avhrr-v02r01.19971101.nc
# Already downloaded: oisst-avhrr-v02r01.19971102.nc
# Already downloaded: oisst-avhrr-v02r01.19971103.nc
# Already downloaded: oisst-avhrr-v02r01.19971104.nc
# Already downloaded: oisst-avhrr-v02r01.19971105.nc
# Already downloaded: oisst-avhrr-v02r01.19971106.nc
# Already downloaded: oisst-avhrr-v02r01.19971107.nc
# Already downloaded: oisst-avhrr-v02r01.19971108.nc
# Already downloaded: oisst-avhrr-v02r01.19971109.nc
# Already downloaded: oisst-avhrr-v02r01.19971110.nc
# Already downloaded: oisst-avhrr-v02r01.19971105.nc
# Already downloaded: oisst-avhrr-v02r01.19971106.nc
# Already downloaded: oisst-avhrr-v02r01.19971107.nc
# Already downloaded: oisst-avhrr-v02r01.19971108.nc
# Already downloaded: oisst-avhrr-v02r01.19971109.nc
# Already downloaded: oisst-avhrr-v02r01.19971110.nc
# Already downloaded: oisst-avhrr-v02r01.19971111.nc
# Already downloaded: oisst-avhrr-v02r01.19971112.nc
# Already downloaded: oisst-avhrr-v02r01.19971113.nc
# Already downloaded: oisst-avhrr-v02r01.19971114.nc
# Already downloaded: oisst-avhrr-v02r01.19971115.nc
# Already downloaded: oisst-avhrr-v02r01.19971116.nc
# Already downloaded: oisst-avhrr-v02r01.19971111.nc
# Already downloaded: oisst-avhrr-v02r01.19971112.nc
# Already downloaded: oisst-avhrr-v02r01.19971113.nc
# Already downloaded: oisst-avhrr-v02r01.19971114.nc
# Already downloaded: oisst-avhrr-v02r01.19971115.nc
# Already downloaded: oisst-avhrr-v02r01.19971116.nc
# Already downloaded: oisst-avhrr-v02r01.19971117.nc
# Already downloaded: oisst-avhrr-v02r01.19971118.nc
# Already downloaded: oisst-avhrr-v02r01.19971119.nc
# Already downloaded: oisst-avhrr-v02r01.19971120.nc
# Already downloaded: oisst-avhrr-v02r01.19971121.nc
# Already downloaded: oisst-avhrr-v02r01.19971117.nc
# Already downloaded: oisst-avhrr-v02r01.19971118.nc
# Already downloaded: oisst-avhrr-v02r01.19971119.nc
# Already downloaded: oisst-avhrr-v02r01.19971120.nc
# Already downloaded: oisst-avhrr-v02r01.19971121.nc
# Already downloaded: oisst-avhrr-v02r01.19971122.nc
# Already downloaded: oisst-avhrr-v02r01.19971123.nc
# Already downloaded: oisst-avhrr-v02r01.19971124.nc
# Already downloaded: oisst-avhrr-v02r01.19971125.nc
# Already downloaded: oisst-avhrr-v02r01.19971126.nc
# Already downloaded: oisst-avhrr-v02r01.19971122.nc
# Already downloaded: oisst-avhrr-v02r01.19971123.nc
# Already downloaded: oisst-avhrr-v02r01.19971124.nc
# Already downloaded: oisst-avhrr-v02r01.19971125.nc
# Already downloaded: oisst-avhrr-v02r01.19971126.nc
# Already downloaded: oisst-avhrr-v02r01.19971127.nc
# Already downloaded: oisst-avhrr-v02r01.19971128.nc
# Already downloaded: oisst-avhrr-v02r01.19971129.nc
# Already downloaded: oisst-avhrr-v02r01.19971130.nc
# Already downloaded: oisst-avhrr-v02r01.19971201.nc
# Already downloaded: oisst-avhrr-v02r01.19971127.nc
# Already downloaded: oisst-avhrr-v02r01.19971128.nc
# Already downloaded: oisst-avhrr-v02r01.19971129.nc
# Already downloaded: oisst-avhrr-v02r01.19971130.nc
# Already downloaded: oisst-avhrr-v02r01.19971201.nc
# Already downloaded: oisst-avhrr-v02r01.19971202.nc
# Already downloaded: oisst-avhrr-v02r01.19971203.nc
# Already downloaded: oisst-avhrr-v02r01.19971204.nc
# Already downloaded: oisst-avhrr-v02r01.19971205.nc
# Already downloaded: oisst-avhrr-v02r01.19971206.nc
# Already downloaded: oisst-avhrr-v02r01.19971202.nc
# Already downloaded: oisst-avhrr-v02r01.19971203.nc
# Already downloaded: oisst-avhrr-v02r01.19971204.nc
# Already downloaded: oisst-avhrr-v02r01.19971205.nc
# Already downloaded: oisst-avhrr-v02r01.19971206.nc
# Already downloaded: oisst-avhrr-v02r01.19971207.nc
# Already downloaded: oisst-avhrr-v02r01.19971208.nc
# Already downloaded: oisst-avhrr-v02r01.19971209.nc
# Already downloaded: oisst-avhrr-v02r01.19971210.nc
# Already downloaded: oisst-avhrr-v02r01.19971211.nc
# Already downloaded: oisst-avhrr-v02r01.19971207.nc
# Already downloaded: oisst-avhrr-v02r01.19971208.nc
# Already downloaded: oisst-avhrr-v02r01.19971209.nc
# Already downloaded: oisst-avhrr-v02r01.19971210.nc
# Already downloaded: oisst-avhrr-v02r01.19971211.nc
# Already downloaded: oisst-avhrr-v02r01.19971212.nc
# Already downloaded: oisst-avhrr-v02r01.19971213.nc
# Already downloaded: oisst-avhrr-v02r01.19971214.nc
# Already downloaded: oisst-avhrr-v02r01.19971215.nc
# Already downloaded: oisst-avhrr-v02r01.19971216.nc
# Already downloaded: oisst-avhrr-v02r01.19971217.nc
# Already downloaded: oisst-avhrr-v02r01.19971212.nc
# Already downloaded: oisst-avhrr-v02r01.19971213.nc
# Already downloaded: oisst-avhrr-v02r01.19971214.nc
# Already downloaded: oisst-avhrr-v02r01.19971215.nc
# Already downloaded: oisst-avhrr-v02r01.19971216.nc
# Already downloaded: oisst-avhrr-v02r01.19971217.nc
# Already downloaded: oisst-avhrr-v02r01.19971218.nc
# Already downloaded: oisst-avhrr-v02r01.19971219.nc
# Already downloaded: oisst-avhrr-v02r01.19971220.nc
# Already downloaded: oisst-avhrr-v02r01.19971221.nc
# Already downloaded: oisst-avhrr-v02r01.19971222.nc
# Already downloaded: oisst-avhrr-v02r01.19971218.nc
# Already downloaded: oisst-avhrr-v02r01.19971219.nc
# Already downloaded: oisst-avhrr-v02r01.19971220.nc
# Already downloaded: oisst-avhrr-v02r01.19971221.nc
# Already downloaded: oisst-avhrr-v02r01.19971222.nc
# Already downloaded: oisst-avhrr-v02r01.19971223.nc
# Already downloaded: oisst-avhrr-v02r01.19971224.nc
# Already downloaded: oisst-avhrr-v02r01.19971225.nc
# Already downloaded: oisst-avhrr-v02r01.19971226.nc
# Already downloaded: oisst-avhrr-v02r01.19971227.nc
# Already downloaded: oisst-avhrr-v02r01.19971228.nc
# Already downloaded: oisst-avhrr-v02r01.19971223.nc
# Already downloaded: oisst-avhrr-v02r01.19971224.nc
# Already downloaded: oisst-avhrr-v02r01.19971225.nc
# Already downloaded: oisst-avhrr-v02r01.19971226.nc
# Already downloaded: oisst-avhrr-v02r01.19971227.nc
# Already downloaded: oisst-avhrr-v02r01.19971228.nc
# Already downloaded: oisst-avhrr-v02r01.19971229.nc
# Already downloaded: oisst-avhrr-v02r01.19971230.nc
# Already downloaded: oisst-avhrr-v02r01.19971231.nc
# ✅ Saved 1981: 122 records to D:/GitHub/Prediction of El-Nino Events/data/raw/csv/nino34_sst_1981.csv
# ✅ Saved 1982: 365 records to D:/GitHub/Prediction of El-Nino Events/data/raw/csv/nino34_sst_1982.csv
# ✅ Saved 1983: 365 records to D:/GitHub/Prediction of El-Nino Events/data/raw/csv/nino34_sst_1983.csv
# ✅ Saved 1984: 366 records to D:/GitHub/Prediction of El-Nino Events/data/raw/csv/nino34_sst_1984.csv
# ✅ Saved 1985: 365 records to D:/GitHub/Prediction of El-Nino Events/data/raw/csv/nino34_sst_1985.csv
# ✅ Saved 1986: 365 records to D:/GitHub/Prediction of El-Nino Events/data/raw/csv/nino34_sst_1986.csv
# ✅ Saved 1987: 365 records to D:/GitHub/Prediction of El-Nino Events/data/raw/csv/nino34_sst_1987.csv
# ✅ Saved 1988: 366 records to D:/GitHub/Prediction of El-Nino Events/data/raw/csv/nino34_sst_1988.csv
# Already downloaded: oisst-avhrr-v02r01.19971229.nc
# Already downloaded: oisst-avhrr-v02r01.19971230.nc
# Already downloaded: oisst-avhrr-v02r01.19971231.nc
# ✅ Saved 1981: 122 records to D:/GitHub/Prediction of El-Nino Events/data/raw/csv/nino34_sst_1981.csv
# ✅ Saved 1982: 365 records to D:/GitHub/Prediction of El-Nino Events/data/raw/csv/nino34_sst_1982.csv
# ✅ Saved 1983: 365 records to D:/GitHub/Prediction of El-Nino Events/data/raw/csv/nino34_sst_1983.csv
# ✅ Saved 1984: 366 records to D:/GitHub/Prediction of El-Nino Events/data/raw/csv/nino34_sst_1984.csv
# ✅ Saved 1985: 365 records to D:/GitHub/Prediction of El-Nino Events/data/raw/csv/nino34_sst_1985.csv
# ✅ Saved 1986: 365 records to D:/GitHub/Prediction of El-Nino Events/data/raw/csv/nino34_sst_1986.csv
# ✅ Saved 1987: 365 records to D:/GitHub/Prediction of El-Nino Events/data/raw/csv/nino34_sst_1987.csv
# ✅ Saved 1988: 366 records to D:/GitHub/Prediction of El-Nino Events/data/raw/csv/nino34_sst_1988.csv
# ✅ Saved 1989: 365 records to D:/GitHub/Prediction of El-Nino Events/data/raw/csv/nino34_sst_1989.csv
# ✅ Saved 1990: 365 records to D:/GitHub/Prediction of El-Nino Events/data/raw/csv/nino34_sst_1990.csv
# ✅ Saved 1991: 365 records to D:/GitHub/Prediction of El-Nino Events/data/raw/csv/nino34_sst_1991.csv
# ✅ Saved 1992: 366 records to D:/GitHub/Prediction of El-Nino Events/data/raw/csv/nino34_sst_1992.csv
# ✅ Saved 1993: 365 records to D:/GitHub/Prediction of El-Nino Events/data/raw/csv/nino34_sst_1993.csv
# ✅ Saved 1994: 365 records to D:/GitHub/Prediction of El-Nino Events/data/raw/csv/nino34_sst_1994.csv
# ✅ Saved 1995: 365 records to D:/GitHub/Prediction of El-Nino Events/data/raw/csv/nino34_sst_1995.csv
# ✅ Saved 1996: 366 records to D:/GitHub/Prediction of El-Nino Events/data/raw/csv/nino34_sst_1996.csv
# ✅ Saved 1997: 365 records to D:/GitHub/Prediction of El-Nino Events/data/raw/csv/nino34_sst_1997.csv
#
# 📊 Total records processed: 5966
# 📅 Years covered: 1981 to 1997
# ✅ Saved 1989: 365 records to D:/GitHub/Prediction of El-Nino Events/data/raw/csv/nino34_sst_1989.csv
# ✅ Saved 1990: 365 records to D:/GitHub/Prediction of El-Nino Events/data/raw/csv/nino34_sst_1990.csv
# ✅ Saved 1991: 365 records to D:/GitHub/Prediction of El-Nino Events/data/raw/csv/nino34_sst_1991.csv
# ✅ Saved 1992: 366 records to D:/GitHub/Prediction of El-Nino Events/data/raw/csv/nino34_sst_1992.csv
# ✅ Saved 1993: 365 records to D:/GitHub/Prediction of El-Nino Events/data/raw/csv/nino34_sst_1993.csv
# ✅ Saved 1994: 365 records to D:/GitHub/Prediction of El-Nino Events/data/raw/csv/nino34_sst_1994.csv
# ✅ Saved 1995: 365 records to D:/GitHub/Prediction of El-Nino Events/data/raw/csv/nino34_sst_1995.csv
# ✅ Saved 1996: 366 records to D:/GitHub/Prediction of El-Nino Events/data/raw/csv/nino34_sst_1996.csv
# ✅ Saved 1997: 365 records to D:/GitHub/Prediction of El-Nino Events/data/raw/csv/nino34_sst_1997.csv
#
# 📊 Total records processed: 5966
# 📅 Years covered: 1981 to 1997

# %%
# Nino 3.4 sst data
input_csv = 'D:/GitHub/Prediction of El-Nino Events/data/raw/csv'
output_csv = 'D:/GitHub/Prediction of El-Nino Events/data/raw/nino.csv'

# Empty dataframe
dfs = []

# Combining csv files
for file in os.listdir(csv):
    if file.endswith('.csv'):
        df = pd.read_csv(os.path.join(csv,file))
        if df.columns[0] == '0':
            df.columns = df.iloc[0]
            df = df.drop(0).reset_index(drop=True)
        dfs.append(df)
df_nino = pd.concat(dfs)
df_nino.to_csv(output_csv, index=False)
if os.path.exists(output_csv):
    print(f'CSV combined sucessfully and combined CSV in this location: {output_csv}')
    print(f'Total records added: {len(df_nino)}')
# Out:
# CSV combined sucessfully and combined CSV is in D:/GitHub/Prediction of El-Nino Events/data/raw/nino.csv
# Total records added: 5966
