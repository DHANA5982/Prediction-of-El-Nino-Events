# %% [markdown]
# # Prediction of El-Nino and La-Nino Events

# %% [markdown]
# ## Extrat, Transform and Load

# %%
import os
import requests
from datetime import datetime, timedelta
import xarray as xr
import numpy as np
import pandas as pd

# %% [markdown]
# ### Web Scrape and Download Historical Optimum Interpolation Sea Surface Temperature (OISST or SST) Data

# %%
# === USER SETTINGS ===
download_dir = "D:/GitHub/Prediction of El-Nino Events/data/raw/oisst_data"
base_url = "https://www.ncei.noaa.gov/data/sea-surface-temperature-optimum-interpolation/v2.1/access/avhrr"

# === Ensure download directory exists ===
os.makedirs(download_dir, exist_ok=True)

# === Helper function to download a single file ==
def download_nc_file(date):
    if date.date() > pd.to_datetime('2025-7-23').date():
        filename = f"oisst-avhrr-v02r01.{date.strftime('%Y%m%d')}_preliminary.nc"
        file_url = f"{base_url}/{date.year}{date.month:02d}/{filename}"
        local_path = os.path.join(download_dir, filename)
    else: 
        filename = f"oisst-avhrr-v02r01.{date.strftime('%Y%m%d')}.nc"
        file_url = f"{base_url}/{date.year}{date.month:02d}/{filename}"
        local_path = os.path.join(download_dir, filename)

    if os.path.exists(local_path):
        print(f"Already downloaded: {filename}")
        return local_path

    print(f"Downloading: {file_url}")
    response = requests.get(file_url)
    if response.status_code == 200:
        with open(local_path, 'wb') as f:
            f.write(response.content)
        return local_path
    else:
        print(f"Failed to download {filename} (status {response.status_code})")
        return None

# %% [markdown]
# ### Extract SST Data for the Nino Region (Nino 3.4) from file

# %%
# === Helper function to extract Niño 3.4 SST from a file ===
def extract_nino34_sst(filepath):
    try:
        ds = xr.open_dataset(filepath)

        # Convert lon to 0–360 if needed
        if ds.lon.max() <= 180:
            ds = ds.assign_coords(lon=((ds.lon + 360) % 360))

        # Define Niño 3.4 box (5N–5S, 170W–120W => lat -5 to 5, lon 190 to 240)
        region = ds.sel(lat=slice(-5, 5), lon=slice(190, 240))
        sst = region['sst'].where(region['sst'] > -100)  # Mask land

        weights = np.cos(np.deg2rad(sst.lat))
        weighted_sst = sst.weighted(weights)

        sst_mean = weighted_sst.mean(dim=['lat', 'lon']).values.item()
        date = ds['time'].values.item()

        return {'date': pd.to_datetime(date), 'sst': round(sst_mean, 2)}
    except Exception as e:
        print(f"Error processing {filepath}: {e}")
        return None

# %% [markdown]
# ### Load SST Data into CSV file in Yearly Basis

# %%
# === INPUT DATE RANGE ===
start_date = datetime(2025, 1, 1)
end_date = datetime(2025, 8, 7)

# %%
# === Main Loop ===
current = start_date
records = []

while current <= end_date:
    file_path = download_nc_file(current)
    if file_path:
        result = extract_nino34_sst(file_path)
        if result:
            records.append(result)
    current += timedelta(days=1)

# === Save results to CSV by year ===
if records:
    df = pd.DataFrame(records)
    df.sort_values('date', inplace=True)
    
    # Group by year and save separate files
    df['year'] = pd.to_datetime(df['date']).dt.year
    
    for year in df['year'].unique():
        year_data = df[df['year'] == year].drop('year', axis=1)
        year_csv = f"D:/GitHub/Prediction of El-Nino Events/data/raw/csv/nino34_sst_{year}.csv"
        year_data.to_csv(year_csv, index=False)
        print(f"✅ Saved {year}: {len(year_data)} records to {year_csv}")
    
    print(f"\n📊 Total records processed: {len(df)}")
    print(f"📅 Years covered: {df['year'].min()} to {df['year'].max()}")
else:
    print("No data extracted.")
# Out:
# Already downloaded: oisst-avhrr-v02r01.20250101.nc
# Already downloaded: oisst-avhrr-v02r01.20250102.nc
# Already downloaded: oisst-avhrr-v02r01.20250103.nc
# Already downloaded: oisst-avhrr-v02r01.20250104.nc
# Already downloaded: oisst-avhrr-v02r01.20250105.nc
# Already downloaded: oisst-avhrr-v02r01.20250106.nc
# Already downloaded: oisst-avhrr-v02r01.20250107.nc
# Already downloaded: oisst-avhrr-v02r01.20250108.nc
# Already downloaded: oisst-avhrr-v02r01.20250109.nc
# Already downloaded: oisst-avhrr-v02r01.20250110.nc
# Already downloaded: oisst-avhrr-v02r01.20250111.nc
# Already downloaded: oisst-avhrr-v02r01.20250112.nc
# Already downloaded: oisst-avhrr-v02r01.20250113.nc
# Already downloaded: oisst-avhrr-v02r01.20250114.nc
# Already downloaded: oisst-avhrr-v02r01.20250115.nc
# Already downloaded: oisst-avhrr-v02r01.20250116.nc
# Already downloaded: oisst-avhrr-v02r01.20250117.nc
# Already downloaded: oisst-avhrr-v02r01.20250118.nc
# Already downloaded: oisst-avhrr-v02r01.20250119.nc
# Already downloaded: oisst-avhrr-v02r01.20250120.nc
# Already downloaded: oisst-avhrr-v02r01.20250121.nc
# Already downloaded: oisst-avhrr-v02r01.20250122.nc
# Already downloaded: oisst-avhrr-v02r01.20250123.nc
# Already downloaded: oisst-avhrr-v02r01.20250124.nc
# Already downloaded: oisst-avhrr-v02r01.20250125.nc
# Already downloaded: oisst-avhrr-v02r01.20250126.nc
# Already downloaded: oisst-avhrr-v02r01.20250127.nc
# Already downloaded: oisst-avhrr-v02r01.20250128.nc
# Already downloaded: oisst-avhrr-v02r01.20250129.nc
# Already downloaded: oisst-avhrr-v02r01.20250130.nc
# Already downloaded: oisst-avhrr-v02r01.20250131.nc
# Already downloaded: oisst-avhrr-v02r01.20250201.nc
# Already downloaded: oisst-avhrr-v02r01.20250202.nc
# Already downloaded: oisst-avhrr-v02r01.20250203.nc
# Already downloaded: oisst-avhrr-v02r01.20250204.nc
# Already downloaded: oisst-avhrr-v02r01.20250205.nc
# Already downloaded: oisst-avhrr-v02r01.20250206.nc
# Already downloaded: oisst-avhrr-v02r01.20250207.nc
# Already downloaded: oisst-avhrr-v02r01.20250208.nc
# Already downloaded: oisst-avhrr-v02r01.20250209.nc
# Already downloaded: oisst-avhrr-v02r01.20250210.nc
# Already downloaded: oisst-avhrr-v02r01.20250211.nc
# Already downloaded: oisst-avhrr-v02r01.20250212.nc
# Already downloaded: oisst-avhrr-v02r01.20250213.nc
# Already downloaded: oisst-avhrr-v02r01.20250214.nc
# Already downloaded: oisst-avhrr-v02r01.20250215.nc
# Already downloaded: oisst-avhrr-v02r01.20250216.nc
# Already downloaded: oisst-avhrr-v02r01.20250217.nc
# Already downloaded: oisst-avhrr-v02r01.20250218.nc
# Already downloaded: oisst-avhrr-v02r01.20250219.nc
# Already downloaded: oisst-avhrr-v02r01.20250220.nc
# Already downloaded: oisst-avhrr-v02r01.20250221.nc
# Already downloaded: oisst-avhrr-v02r01.20250222.nc
# Already downloaded: oisst-avhrr-v02r01.20250223.nc
# Already downloaded: oisst-avhrr-v02r01.20250224.nc
# Already downloaded: oisst-avhrr-v02r01.20250225.nc
# Already downloaded: oisst-avhrr-v02r01.20250226.nc
# Already downloaded: oisst-avhrr-v02r01.20250227.nc
# Already downloaded: oisst-avhrr-v02r01.20250228.nc
# Already downloaded: oisst-avhrr-v02r01.20250301.nc
# Already downloaded: oisst-avhrr-v02r01.20250302.nc
# Already downloaded: oisst-avhrr-v02r01.20250303.nc
# Already downloaded: oisst-avhrr-v02r01.20250304.nc
# Already downloaded: oisst-avhrr-v02r01.20250305.nc
# Already downloaded: oisst-avhrr-v02r01.20250306.nc
# Already downloaded: oisst-avhrr-v02r01.20250307.nc
# Already downloaded: oisst-avhrr-v02r01.20250308.nc
# Already downloaded: oisst-avhrr-v02r01.20250309.nc
# Already downloaded: oisst-avhrr-v02r01.20250310.nc
# Already downloaded: oisst-avhrr-v02r01.20250311.nc
# Already downloaded: oisst-avhrr-v02r01.20250312.nc
# Already downloaded: oisst-avhrr-v02r01.20250313.nc
# Already downloaded: oisst-avhrr-v02r01.20250314.nc
# Already downloaded: oisst-avhrr-v02r01.20250315.nc
# Already downloaded: oisst-avhrr-v02r01.20250316.nc
# Already downloaded: oisst-avhrr-v02r01.20250317.nc
# Already downloaded: oisst-avhrr-v02r01.20250318.nc
# Already downloaded: oisst-avhrr-v02r01.20250319.nc
# Already downloaded: oisst-avhrr-v02r01.20250320.nc
# Already downloaded: oisst-avhrr-v02r01.20250321.nc
# Already downloaded: oisst-avhrr-v02r01.20250322.nc
# Already downloaded: oisst-avhrr-v02r01.20250323.nc
# Already downloaded: oisst-avhrr-v02r01.20250324.nc
# Already downloaded: oisst-avhrr-v02r01.20250325.nc
# Already downloaded: oisst-avhrr-v02r01.20250326.nc
# Already downloaded: oisst-avhrr-v02r01.20250327.nc
# Already downloaded: oisst-avhrr-v02r01.20250328.nc
# Already downloaded: oisst-avhrr-v02r01.20250329.nc
# Already downloaded: oisst-avhrr-v02r01.20250330.nc
# Already downloaded: oisst-avhrr-v02r01.20250331.nc
# Already downloaded: oisst-avhrr-v02r01.20250401.nc
# Already downloaded: oisst-avhrr-v02r01.20250402.nc
# Already downloaded: oisst-avhrr-v02r01.20250403.nc
# Already downloaded: oisst-avhrr-v02r01.20250404.nc
# Already downloaded: oisst-avhrr-v02r01.20250405.nc
# Already downloaded: oisst-avhrr-v02r01.20250406.nc
# Already downloaded: oisst-avhrr-v02r01.20250407.nc
# Already downloaded: oisst-avhrr-v02r01.20250408.nc
# Already downloaded: oisst-avhrr-v02r01.20250409.nc
# Already downloaded: oisst-avhrr-v02r01.20250410.nc
# Already downloaded: oisst-avhrr-v02r01.20250411.nc
# Already downloaded: oisst-avhrr-v02r01.20250412.nc
# Already downloaded: oisst-avhrr-v02r01.20250413.nc
# Already downloaded: oisst-avhrr-v02r01.20250414.nc
# Already downloaded: oisst-avhrr-v02r01.20250415.nc
# Already downloaded: oisst-avhrr-v02r01.20250416.nc
# Already downloaded: oisst-avhrr-v02r01.20250417.nc
# Already downloaded: oisst-avhrr-v02r01.20250418.nc
# Already downloaded: oisst-avhrr-v02r01.20250419.nc
# Already downloaded: oisst-avhrr-v02r01.20250420.nc
# Already downloaded: oisst-avhrr-v02r01.20250421.nc
# Already downloaded: oisst-avhrr-v02r01.20250422.nc
# Already downloaded: oisst-avhrr-v02r01.20250423.nc
# Already downloaded: oisst-avhrr-v02r01.20250424.nc
# Already downloaded: oisst-avhrr-v02r01.20250425.nc
# Already downloaded: oisst-avhrr-v02r01.20250426.nc
# Already downloaded: oisst-avhrr-v02r01.20250427.nc
# Already downloaded: oisst-avhrr-v02r01.20250428.nc
# Already downloaded: oisst-avhrr-v02r01.20250429.nc
# Already downloaded: oisst-avhrr-v02r01.20250430.nc
# Already downloaded: oisst-avhrr-v02r01.20250501.nc
# Already downloaded: oisst-avhrr-v02r01.20250502.nc
# Already downloaded: oisst-avhrr-v02r01.20250503.nc
# Already downloaded: oisst-avhrr-v02r01.20250504.nc
# Already downloaded: oisst-avhrr-v02r01.20250505.nc
# Already downloaded: oisst-avhrr-v02r01.20250506.nc
# Already downloaded: oisst-avhrr-v02r01.20250507.nc
# Already downloaded: oisst-avhrr-v02r01.20250508.nc
# Already downloaded: oisst-avhrr-v02r01.20250509.nc
# Already downloaded: oisst-avhrr-v02r01.20250510.nc
# Already downloaded: oisst-avhrr-v02r01.20250511.nc
# Already downloaded: oisst-avhrr-v02r01.20250512.nc
# Already downloaded: oisst-avhrr-v02r01.20250513.nc
# Already downloaded: oisst-avhrr-v02r01.20250514.nc
# Already downloaded: oisst-avhrr-v02r01.20250515.nc
# Already downloaded: oisst-avhrr-v02r01.20250516.nc
# Already downloaded: oisst-avhrr-v02r01.20250517.nc
# Already downloaded: oisst-avhrr-v02r01.20250518.nc
# Already downloaded: oisst-avhrr-v02r01.20250519.nc
# Already downloaded: oisst-avhrr-v02r01.20250520.nc
# Already downloaded: oisst-avhrr-v02r01.20250521.nc
# Already downloaded: oisst-avhrr-v02r01.20250522.nc
# Already downloaded: oisst-avhrr-v02r01.20250523.nc
# Already downloaded: oisst-avhrr-v02r01.20250524.nc
# Already downloaded: oisst-avhrr-v02r01.20250525.nc
# Already downloaded: oisst-avhrr-v02r01.20250526.nc
# Already downloaded: oisst-avhrr-v02r01.20250527.nc
# Already downloaded: oisst-avhrr-v02r01.20250528.nc
# Already downloaded: oisst-avhrr-v02r01.20250529.nc
# Already downloaded: oisst-avhrr-v02r01.20250530.nc
# Already downloaded: oisst-avhrr-v02r01.20250531.nc
# Already downloaded: oisst-avhrr-v02r01.20250601.nc
# Already downloaded: oisst-avhrr-v02r01.20250602.nc
# Already downloaded: oisst-avhrr-v02r01.20250603.nc
# Already downloaded: oisst-avhrr-v02r01.20250604.nc
# Already downloaded: oisst-avhrr-v02r01.20250605.nc
# Already downloaded: oisst-avhrr-v02r01.20250606.nc
# Already downloaded: oisst-avhrr-v02r01.20250607.nc
# Already downloaded: oisst-avhrr-v02r01.20250608.nc
# Already downloaded: oisst-avhrr-v02r01.20250609.nc
# Already downloaded: oisst-avhrr-v02r01.20250610.nc
# Already downloaded: oisst-avhrr-v02r01.20250611.nc
# Already downloaded: oisst-avhrr-v02r01.20250612.nc
# Already downloaded: oisst-avhrr-v02r01.20250613.nc
# Already downloaded: oisst-avhrr-v02r01.20250614.nc
# Already downloaded: oisst-avhrr-v02r01.20250615.nc
# Already downloaded: oisst-avhrr-v02r01.20250616.nc
# Already downloaded: oisst-avhrr-v02r01.20250617.nc
# Already downloaded: oisst-avhrr-v02r01.20250618.nc
# Already downloaded: oisst-avhrr-v02r01.20250619.nc
# Already downloaded: oisst-avhrr-v02r01.20250620.nc
# Already downloaded: oisst-avhrr-v02r01.20250621.nc
# Already downloaded: oisst-avhrr-v02r01.20250622.nc
# Already downloaded: oisst-avhrr-v02r01.20250623.nc
# Already downloaded: oisst-avhrr-v02r01.20250624.nc
# Already downloaded: oisst-avhrr-v02r01.20250625.nc
# Already downloaded: oisst-avhrr-v02r01.20250626.nc
# Already downloaded: oisst-avhrr-v02r01.20250627.nc
# Already downloaded: oisst-avhrr-v02r01.20250628.nc
# Already downloaded: oisst-avhrr-v02r01.20250629.nc
# Already downloaded: oisst-avhrr-v02r01.20250630.nc
# Already downloaded: oisst-avhrr-v02r01.20250701.nc
# Already downloaded: oisst-avhrr-v02r01.20250702.nc
# Already downloaded: oisst-avhrr-v02r01.20250703.nc
# Already downloaded: oisst-avhrr-v02r01.20250704.nc
# Already downloaded: oisst-avhrr-v02r01.20250705.nc
# Already downloaded: oisst-avhrr-v02r01.20250706.nc
# Already downloaded: oisst-avhrr-v02r01.20250707.nc
# Already downloaded: oisst-avhrr-v02r01.20250708.nc
# Already downloaded: oisst-avhrr-v02r01.20250709.nc
# Already downloaded: oisst-avhrr-v02r01.20250710.nc
# Already downloaded: oisst-avhrr-v02r01.20250711.nc
# Already downloaded: oisst-avhrr-v02r01.20250712.nc
# Already downloaded: oisst-avhrr-v02r01.20250713.nc
# Already downloaded: oisst-avhrr-v02r01.20250714.nc
# Already downloaded: oisst-avhrr-v02r01.20250715.nc
# Already downloaded: oisst-avhrr-v02r01.20250716.nc
# Already downloaded: oisst-avhrr-v02r01.20250717.nc
# Already downloaded: oisst-avhrr-v02r01.20250718.nc
# Already downloaded: oisst-avhrr-v02r01.20250719.nc
# Already downloaded: oisst-avhrr-v02r01.20250720.nc
# Already downloaded: oisst-avhrr-v02r01.20250721.nc
# Already downloaded: oisst-avhrr-v02r01.20250722.nc
# Already downloaded: oisst-avhrr-v02r01.20250723.nc
# Already downloaded: oisst-avhrr-v02r01.20250724_preliminary.nc
# Already downloaded: oisst-avhrr-v02r01.20250725_preliminary.nc
# Already downloaded: oisst-avhrr-v02r01.20250726_preliminary.nc
# Already downloaded: oisst-avhrr-v02r01.20250727_preliminary.nc
# Already downloaded: oisst-avhrr-v02r01.20250728_preliminary.nc
# Already downloaded: oisst-avhrr-v02r01.20250729_preliminary.nc
# Already downloaded: oisst-avhrr-v02r01.20250730_preliminary.nc
# Already downloaded: oisst-avhrr-v02r01.20250731_preliminary.nc
# Already downloaded: oisst-avhrr-v02r01.20250801_preliminary.nc
# Already downloaded: oisst-avhrr-v02r01.20250802_preliminary.nc
# Already downloaded: oisst-avhrr-v02r01.20250803_preliminary.nc
# Already downloaded: oisst-avhrr-v02r01.20250804_preliminary.nc
# Already downloaded: oisst-avhrr-v02r01.20250805_preliminary.nc
# Already downloaded: oisst-avhrr-v02r01.20250806_preliminary.nc
# Already downloaded: oisst-avhrr-v02r01.20250807_preliminary.nc
# ✅ Saved 2025: 219 records to D:/GitHub/Prediction of El-Nino Events/data/raw/csv/nino34_sst_2025.csv
#
# 📊 Total records processed: 219
# 📅 Years covered: 2025 to 2025

# %% [markdown]
# ### Final Combined CSV file

# %%
# Nino 3.4 sst data
input_csv = 'D:/GitHub/Prediction of El-Nino Events/data/raw/csv'
output_csv = 'D:/GitHub/Prediction of El-Nino Events/data/raw/nino.csv'

# Empty dataframe
dfs = []

# Combining csv files
for file in os.listdir(input_csv):
    if file.endswith('.csv'):
        df = pd.read_csv(os.path.join(input_csv,file))
        if df.columns[0] == '0':
            df.columns = df.iloc[0]
            df = df.drop(0).reset_index(drop=True)
        dfs.append(df)
df_nino = pd.concat(dfs)
df_nino.to_csv(output_csv, index=False)
if os.path.exists(output_csv):
    print(f'CSV combined sucessfully and combined CSV in this location: {output_csv}')
    print(f'Total records added: {len(df_nino)}')
# Out:
# CSV combined sucessfully and combined CSV in this location: D:/GitHub/Prediction of El-Nino Events/data/raw/nino.csv
# Total records added: 16047
